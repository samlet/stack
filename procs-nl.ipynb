# %%
from sagas.nlu.uni_remote_viz import viz_sample
viz_sample('nl', 'Schrijf je een boek?', 'spacy')
# Out:
# .. request is {'lang': 'nl', 'sents': 'Schrijf je een boek?', 'engine': 'spacy', 'pipelines': ['predicts']}
# words count 5
# ✁ chunks. -------------------------
# ❶ verb_domains(schrijven) _
#      rel  index  text lemma     children  \
# 0  nsubj      2    je    je         [je]
# 1    obj      4  boek  boek  [een, boek]
# 2  punct      5     ?     ?          [?]
#
#                                            features
# 0  [c_pron, x_pron|onbep|neut|zelfst__prontype=ind]
# 1          [c_noun, x_n|soort|ev|neut__number=sing]
# 2           [c_punct, x_punc|vraag__puncttype=qest]
# obj -> een boek
# ♥ Schrijf/schrijven(verb_domains): writing.n.04, letter.n.01...
# ♥ boek(obj): quire.n.01, book.n.10, bo...
# ✁ dependency-graph. -------------------------
#    index     text      lemma   upos  \
# 0      1  Schrijf  schrijven   VERB
# 1      2       je         je   PRON
# 2      3      een        een    DET
# 3      4     boek       boek   NOUN
# 4      5        ?          ?  PUNCT
#
# ...
