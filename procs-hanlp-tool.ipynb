# %%
from sagas.bots.jupyter_tool import visual_sents
# visual_sents('我要找一本课本')
visual_sents('我要找一个商品', ['mq', 'nr', 'n'])
# Out:
#    start  end value entity
# 0      0    1     我      r
# 1      1    2     要      v
# 2      2    3     找      v
# 3      3    5    一个     mq
# 4      5    7    商品      n
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     padding: 0.15em;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#     </style><div class="markup tex2jax_ignore">我要找<mark>一个</mark><mark>商品</mark></div>

# %%
from sagas.bots.hanlp_viz import HanlpProtoViz
HanlpProtoViz().analyse('我要找一本英语书')
# Out:
# 我 --[主谓关系](SBV)--> 找
# 要 --[状中结构](ADV)--> 找
# 找 --[核心关系](HED)--> ##核心##
# 一 --[定中关系](ATT)--> 本
# 本 --[定中关系](ATT)--> 英语书
# 英语书 --[动宾关系](VOB)--> 找

# %%
from sagas.bots.hanlp_client import HanlpClient
# HanlpClient().disp_deps('苹果电脑可以运行开源阿尔法狗代码吗')
HanlpClient().disp_deps('我要找上星期销量最好的商品')
# Out:
# ✔ 	actor: 我
# 	rel.v(ADV): 要
# 	rel.v(CMP): 上
# 	object: 商品
# ♟ sbv 我
# 	► vob.head 找
# 		✜ vob 商品
# zh_SBV|id 1
# zh_VOB|head_id 3
# zh_VOB shang pin
# zh_SBV|head_id 3
# zh_SBV wo
# zh_VOB|text 商品
# zh_VOB@zh 商品
# zh_VOB|head 找
# zh_VOB|id 9
# zh_SBV|text 我
# zh_SBV@zh 我
# zh_SBV|head 找

# %%
from sagas.bots.hanlp_client import HanlpClient
HanlpClient().disp_deps('我要找上星期销量最好的雨伞')
# Out:
# ✔ 	actor: 我
# 	rel.v(ADV): 要
# 	rel.v(CMP): 上
# 	object: 雨伞
# ♟ sbv 我
# 	► vob.head 找
# 		✜ vob 雨伞
# zh_SBV|id 1
# zh_VOB|head_id 3
# zh_VOB yu san
# zh_SBV|head_id 3
# zh_SBV wo
# zh_VOB|text 雨伞
# zh_VOB@zh 雨伞
# zh_VOB|head 找
# zh_VOB|id 9
# zh_SBV|text 我
# zh_SBV@zh 我
# zh_SBV|head 找

# %%
visual_sents('我要找上星期销量最好的雨伞', ['t', 'mq', 'nr', 'n'])
# Out:
#    start  end value entity
# 0      0    1     我      r
# 1      1    2     要      v
# 2      2    3     找      v
# 3      3    6   上星期      t
# 4      6    8    销量      n
# 5      8    9     最      d
# 6      9   10     好      a
# 7     10   11     的     uj
# 8     11   13    雨伞      n
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     padding: 0.15em;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#     </style><div class="markup tex2jax_ignore">我要找<mark>上星期</mark><mark>销量</mark>最好的<mark>雨伞</mark></div>
