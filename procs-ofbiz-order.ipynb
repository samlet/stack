# %%
from sagas.ofbiz.entities import search_entity
search_entity('order')
# Out:
# OrderItemTypeAttr
# OrderItemContactMech
# OrderAdjustmentBilling
# OrderReportView
# OrderHeaderNoteView
# OrderItemType
# OrderHeaderWorkEffort
# TrackingCodeOrderAndOrderHeader
# OrderTerm
# OrderReportPurchasesGroupByProduct
# SupplierPrefOrder
# OrderItemAndProductContentInfo
# OrderAdjustmentType
# OrderAdjustment
# OrderItemRole
# OrderItemBillingAndInvoiceAndItem
# OrderItemAndProduct
# MarketingCampaignAndOrderHeader
# OrderItemAssoc
# OrderItemChange
# OrderHeaderAndShipGroupsByProduct
# OrderItemShipGroup
# OrderItemShipGrpInvResAndItem
# TrackingCodeOrderReturn
# OrderHeaderAndShipGroups
# WorkEffortOrderHeaderView
# OrderItemQuantityReportGroupByItem
# OrderItemShipGrpInvResAndItemLocation
# PackedQtyVsOrderItemQuantity
# OrderItemAndShipGrpInvResAndItem
# OrderContactMech
# OrderContent
# OrderHeaderAndItems
# OrderHeaderItemAndInv
# OrderItemAndShipGrpInvResAndItemSum
# OrderHeaderItemAndInvRoles
# OrderItemGroup
# OrderHeaderAndWorkEffort
# TrackingCodeOrder
# ...

# %%
from sagas.ofbiz.entities import OfEntity as e
e('meta').OrderStatus
# Out:
#                         name primary         type   field type
# 0              orderStatusId       *           id           id
# 1                   statusId                   id           id
# 2                    orderId                   id           id
# 3             orderItemSeqId                   id           id
# 4   orderPaymentPreferenceId                   id           id
# 5             statusDatetime            date-time    date-time
# 6            statusUserLogin             id-vlong     id-vlong
# 7               changeReason          description  description
# 8           lastUpdatedStamp            date-time    date-time
# 9         lastUpdatedTxStamp            date-time    date-time
# 10              createdStamp            date-time    date-time
# 11            createdTxStamp            date-time    date-time

# %%
e('relations').OrderStatus
# Out:
#               entity name                relation      type relation type
# 0              StatusItem              StatusItem       one           one
# 1             OrderHeader             OrderHeader       one           one
# 2               OrderItem               OrderItem  one-nofk      one-nofk
# 3  OrderPaymentPreference  OrderPaymentPreference  one-nofk      one-nofk
# 4               UserLogin               UserLogin       one           one

# %%
e('relations').OrderHeader
# Out:
#                    entity name                       relation  type  \
# 0                    OrderType                      OrderType   one
# 1                  Enumeration        SalesChannelEnumeration   one
# 2                     Facility                 OriginFacility   one
# 3                OrderTypeAttr                  OrderTypeAttr  many
# 4               BillingAccount                 BillingAccount   one
# 5                 ProductStore                   ProductStore   one
# 6                 ShoppingList          AutoOrderShoppingList   one
# 7                    UserLogin             CreatedByUserLogin   one
# 8                   StatusItem                     StatusItem   one
# 9                   StatusItem                 SyncStatusItem   one
# 10                         Uom                            Uom   one
# 11                     WebSite                        WebSite   one
# 12     CommunicationEventOrder        CommunicationEventOrder  many
# ...
