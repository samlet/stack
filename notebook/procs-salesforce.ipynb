# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
os.getenv("USERNAME")
# Out:
# 'xiaofei.wu@gmail.com'

# %%
from sagas.salesforce.sfManager import sf_Manager
sf_manager = sf_Manager()

# %%
accounts = sf_manager.get_accounts()
contacts = sf_manager.get_contacts()
users = sf_manager.get_users()

# %%
accounts
# Out:
#                     Id                                 Name
# 0   0014000000HabN6AAJ                                    x
# 1   0014000000HaKzQAAV                            GenePoint
# 2   0014000000HaKzRAAV                 United Oil & Gas, UK
# 3   0014000000HaKzSAAV          United Oil & Gas, Singapore
# 4   0014000000HaKzTAAV                  Edge Communications
# 5   0014000000HaKzUAAV  Burlington Textiles Corp of America
# 6   0014000000HaKzVAAV            Pyramid Construction Inc.
# 7   0014000000HaKzWAAV                        Dickenson plc
# 8   0014000000HaKzXAAV           Grand Hotels & Resorts Ltd
# 9   0014000000HaKzYAAV      Express Logistics and Transport
# 10  0014000000HaKzZAAV                University of Arizona
# 11  0014000000HaKzaAAF               United Oil & Gas Corp.
# 12  0014000000HaKzbAAF                               sForce

# %%
contacts
# Out:
#                     Id Salutation  FirstName   LastName
# 0   0034000000Oex1lAAB       None       None          x
# 1   0034000000OeXJPAA3        Ms.       Rose   Gonzalez
# 2   0034000000OeXJQAA3        Mr.       Sean     Forbes
# 3   0034000000OeXJRAA3        Mr.       Jack     Rogers
# 4   0034000000OeXJSAA3        Ms.        Pat  Stumuller
# 5   0034000000OeXJTAA3         Mr       Andy      Young
# 6   0034000000OeXJUAA3        Mr.        Tim       Barr
# 7   0034000000OeXJVAA3        Mr.       John       Bond
# 8   0034000000OeXJWAA3        Ms.     Stella    Pavlova
# 9   0034000000OeXJXAA3        Ms.     Lauren      Boyle
# 10  0034000000OeXJYAA3        Ms.     Babara       Levy
# 11  0034000000OeXJZAA3        Mr.       Josh      Davis
# 12  0034000000OeXJaAAN        Ms.       Jane       Grey
# 13  0034000000OeXJbAAN        Mr.     Arthur       Song
# 14  0034000000OeXJcAAN        Ms.     Ashley      James
# 15  0034000000OeXJdAAN        Mr.        Tom     Ripley
# 16  0034000000OeXJeAAN        Ms.        Liz     D'Cruz
# 17  0034000000OeXJfAAN        Ms.       Edna      Frank
# 18  0034000000OeXJgAAN        Mr.        Avi      Green
# 19  0034000000OeXJhAAN        Ms.  Siddartha    Nedaerk
# 20  0034000000OeXJiAAN        Mr.       Jake    Llorrac
# 21  0031W00002dbadDQAQ       None       None      Smith

# %%
users
# Out:
#                    Id  FirstName LastName
# 0  00540000001A3akAAC  Automated  Process
# 1  00540000000whTHAAY    Fan Wei  Fan Wei

# %%
opportunities=sf_manager.get_opportunities()
opportunities.head()
# Out:
#   CreatedDate                                         Name  \
# 0  2008-04-24                                     Edge SLA
# 1  2008-04-24               Grand Hotels Kitchen Generator
# 2  2008-04-24                             Grand Hotels SLA
# 3  2008-04-24  Express Logistics Portable Truck Generators
# 4  2008-04-24                        Express Logistics SLA
#
#              StageName  ExpectedRevenue    Amount         LeadSource  IsWon  \
# 0           Closed Won          60000.0   60000.0      Word of mouth   True
# 1  Id. Decision Makers           9000.0   15000.0               None  False
# 2           Closed Won          90000.0   90000.0  External Referral   True
# 3    Value Proposition          40000.0   80000.0  External Referral  False
# 4  Perception Analysis          84000.0  120000.0  External Referral  False
#
#    IsClosed                         Type  Probability
# 0      True  Existing Customer - Upgrade        100.0
# 1     False  Existing Customer - Upgrade         60.0
# 2      True  Existing Customer - Upgrade        100.0
# 3     False  Existing Customer - Upgrade         50.0
# 4     False  Existing Customer - Upgrade         70.0

# %%
def top_lost_opportunities(df):
    df = df[df["StageName"] == "Closed Lost"]
    cols = ["CreatedDate", "Name", "Amount", "StageName"]
    df = df[cols].sort_values("Amount", ascending=False).iloc[:5]
    # only display 21 characters
    df["Name"] = df["Name"].apply(lambda x: x[:30])
    # return df_to_table(df)
    return df

top_lost_opportunities(opportunities)
# Out:
# Empty DataFrame
# Columns: [CreatedDate, Name, Amount, StageName]
# Index: []

# %%
# returns top 5 open opportunities
def top_open_opportunities(df):
    df = df.sort_values("Amount", ascending=True)
    cols = ["CreatedDate", "Name", "Amount", "StageName"]
    df = df[cols].iloc[:5]
    # only display 21 characters
    df["Name"] = df["Name"].apply(lambda x: x[:30])
    return (df)

top_open_opportunities(opportunities)
# Out:
#    CreatedDate                            Name   Amount            StageName
# 27  2008-04-24     Dickenson Mobile Generators  15000.0        Qualification
# 1   2008-04-24  Grand Hotels Kitchen Generator  15000.0  Id. Decision Makers
# 22  2008-04-24                   GenePoint SLA  30000.0           Closed Won
# 24  2008-04-24        Edge Emergency Generator  35000.0  Id. Decision Makers
# 25  2008-04-24               Edge Installation  50000.0           Closed Won

# %%
cases=sf_manager.get_cases()
cases.head()
# Out:
#   CreatedDate        Type                Reason  Status Origin  \
# 0  2008-04-24  Electrical  Equipment Complexity  Closed  Phone
# 1  2008-04-24  Electrical           Performance  Closed  Phone
# 2  2008-04-24  Electrical          Installation     New    Web
# 3  2008-04-24       Other          Installation  Closed    Web
# 4  2008-04-24       Other                 Other  Closed  Phone
#
#                                              Subject Priority  IsClosed  \
# 0        Starting generator after electrical failure     High      True
# 1  Performance inadequate for second consecutive ...     High      True
# 2  Seeking guidance on electrical wiring installa...      Low     False
# 3                          Easy installation process      Low      True
# 4       Maintenance guidelines for generator unclear   Medium      True
#
#               OwnerId  IsDeleted           AccountId
# 0  00540000000whTHAAY      False  0014000000HaKzTAAV
# 1  00540000000whTHAAY      False  0014000000HaKzaAAF
# 2  00540000000whTHAAY      False  0014000000HaKzaAAF
# 3  00540000000whTHAAY      False  0014000000HaKzYAAV
# 4  00540000000whTHAAY      False  0014000000HaKzYAAV

# %%
import pandas as pd

# cases = cases.dropna(subset=["AccountId"])
# cases = pd.merge(cases, accounts, left_on="AccountId", right_on="Id")
cases = cases.groupby(["AccountId"]).count()
cases = cases.sort_values("IsDeleted")
cases
# Out:
#                     CreatedDate  Type  Reason  Status  Origin  Subject  \
# AccountId
# 0014000000HaKzRAAV            1     1       1       1       1        1
# 0014000000HaKzZAAV            1     1       1       1       1        1
# 0014000000HabN6AAJ            1     0       0       1       1        1
# 0014000000HaKzQAAV            2     2       2       2       2        2
# 0014000000HaKzUAAV            2     2       2       2       2        2
# 0014000000HaKzSAAV            3     3       3       3       3        3
# 0014000000HaKzTAAV            3     3       3       3       3        3
# 0014000000HaKzYAAV            3     3       3       3       3        3
# 0014000000HaKzXAAV            4     4       4       4       4        4
# 0014000000HaKzaAAF            7     7       7       7       7        7
#
#                     Priority  IsClosed  OwnerId  IsDeleted
# AccountId
# 0014000000HaKzRAAV         1         1        1          1
# 0014000000HaKzZAAV         1         1        1          1
# 0014000000HabN6AAJ         1         1        1          1
# 0014000000HaKzQAAV         2         2        2          2
# 0014000000HaKzUAAV         2         2        2          2
# 0014000000HaKzSAAV         3         3        3          3
# 0014000000HaKzTAAV         3         3        3          3
# 0014000000HaKzYAAV         3         3        3          3
# 0014000000HaKzXAAV         4         4        4          4
# 0014000000HaKzaAAF         7         7        7          7

# %%
cases=sf_manager.get_cases()
accounts = sf_manager.get_accounts()
m=pd.merge(cases, accounts, left_on="AccountId", right_on="Id")
m.head()
# Out:
#   CreatedDate        Type                Reason  Status Origin  \
# 0  2008-04-24  Electrical  Equipment Complexity  Closed  Phone
# 1  2008-04-24  Mechanical  Equipment Complexity  Closed    Web
# 2  2008-04-24  Electrical  Equipment Complexity  Closed  Phone
# 3  2008-04-24  Electrical           Performance  Closed  Phone
# 4  2008-04-24  Electrical          Installation     New    Web
#
#                                              Subject Priority  IsClosed  \
# 0        Starting generator after electrical failure     High      True
# 1                         Shutting down of generator   Medium      True
# 2    Cannot start generator after electrical failure   Medium      True
# 3  Performance inadequate for second consecutive ...     High      True
# 4  Seeking guidance on electrical wiring installa...      Low     False
#
#               OwnerId  IsDeleted           AccountId                  Id  \
# 0  00540000000whTHAAY      False  0014000000HaKzTAAV  0014000000HaKzTAAV
# 1  00540000000whTHAAY      False  0014000000HaKzTAAV  0014000000HaKzTAAV
# 2  00540000000whTHAAY      False  0014000000HaKzTAAV  0014000000HaKzTAAV
# 3  00540000000whTHAAY      False  0014000000HaKzaAAF  0014000000HaKzaAAF
# 4  00540000000whTHAAY      False  0014000000HaKzaAAF  0014000000HaKzaAAF
#
#                      Name
# 0     Edge Communications
# 1     Edge Communications
# 2     Edge Communications
# 3  United Oil & Gas Corp.
# 4  United Oil & Gas Corp.

# %%
m.groupby(["AccountId", "Name"]).count().sort_values("IsDeleted")
# Out:
#                                                         CreatedDate  Type  \
# AccountId          Name
# 0014000000HaKzRAAV United Oil & Gas, UK                           1     1
# 0014000000HaKzZAAV University of Arizona                          1     1
# 0014000000HabN6AAJ x                                              1     0
# 0014000000HaKzQAAV GenePoint                                      2     2
# 0014000000HaKzUAAV Burlington Textiles Corp of America            2     2
# 0014000000HaKzSAAV United Oil & Gas, Singapore                    3     3
# 0014000000HaKzTAAV Edge Communications                            3     3
# 0014000000HaKzYAAV Express Logistics and Transport                3     3
# 0014000000HaKzXAAV Grand Hotels & Resorts Ltd                     4     4
# 0014000000HaKzaAAF United Oil & Gas Corp.                         7     7
#
#                                                         Reason  Status  \
# AccountId          Name
# 0014000000HaKzRAAV United Oil & Gas, UK                      1       1
# 0014000000HaKzZAAV University of Arizona                     1       1
# 0014000000HabN6AAJ x                                         0       1
# 0014000000HaKzQAAV GenePoint                                 2       2
# 0014000000HaKzUAAV Burlington Textiles Corp of America       2       2
# 0014000000HaKzSAAV United Oil & Gas, Singapore               3       3
# 0014000000HaKzTAAV Edge Communications                       3       3
# 0014000000HaKzYAAV Express Logistics and Transport           3       3
# 0014000000HaKzXAAV Grand Hotels & Resorts Ltd                4       4
# 0014000000HaKzaAAF United Oil & Gas Corp.                    7       7
#
#                                                         Origin  Subject  \
# AccountId          Name
# 0014000000HaKzRAAV United Oil & Gas, UK                      1        1
# 0014000000HaKzZAAV University of Arizona                     1        1
# 0014000000HabN6AAJ x                                         1        1
# 0014000000HaKzQAAV GenePoint                                 2        2
# 0014000000HaKzUAAV Burlington Textiles Corp of America       2        2
# 0014000000HaKzSAAV United Oil & Gas, Singapore               3        3
# 0014000000HaKzTAAV Edge Communications                       3        3
# 0014000000HaKzYAAV Express Logistics and Transport           3        3
# 0014000000HaKzXAAV Grand Hotels & Resorts Ltd                4        4
# 0014000000HaKzaAAF United Oil & Gas Corp.                    7        7
#
#                                                         Priority  IsClosed  \
# AccountId          Name
# 0014000000HaKzRAAV United Oil & Gas, UK                        1         1
# 0014000000HaKzZAAV University of Arizona                       1         1
# 0014000000HabN6AAJ x                                           1         1
# 0014000000HaKzQAAV GenePoint                                   2         2
# 0014000000HaKzUAAV Burlington Textiles Corp of America         2         2
# 0014000000HaKzSAAV United Oil & Gas, Singapore                 3         3
# 0014000000HaKzTAAV Edge Communications                         3         3
# 0014000000HaKzYAAV Express Logistics and Transport             3         3
# 0014000000HaKzXAAV Grand Hotels & Resorts Ltd                  4         4
# 0014000000HaKzaAAF United Oil & Gas Corp.                      7         7
#
#                                                         OwnerId  IsDeleted  Id
# AccountId          Name
# 0014000000HaKzRAAV United Oil & Gas, UK                       1          1   1
# 0014000000HaKzZAAV University of Arizona                      1          1   1
# 0014000000HabN6AAJ x                                          1          1   1
# 0014000000HaKzQAAV GenePoint                                  2          2   2
# 0014000000HaKzUAAV Burlington Textiles Corp of America        2          2   2
# 0014000000HaKzSAAV United Oil & Gas, Singapore                3          3   3
# 0014000000HaKzTAAV Edge Communications                        3          3   3
# 0014000000HaKzYAAV Express Logistics and Transport            3          3   3
# 0014000000HaKzXAAV Grand Hotels & Resorts Ltd                 4          4   4
# 0014000000HaKzaAAF United Oil & Gas Corp.                     7          7   7

# %%
query_text = "SELECT CreatedDate, Name, StageName, ExpectedRevenue, Amount, LeadSource, IsWon, IsClosed, Type, Probability FROM Opportunity"
try:
    query_result = sf_manager.sf.query(query_text)
except SalesforceExpiredSession as e:
    sf_manager.login()
    query_result = self.sf.query(query_text)
opportunities = sf_manager.dict_to_df(query_result)
query_result
# Out:
# OrderedDict([('totalSize', 31),
#              ('done', True),
#              ('records',
#               [OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9myAAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Edge SLA'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 60000.0),
#                             ('Amount', 60000.0),
#                             ('LeadSource', 'Word of mouth'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9mzAAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Grand Hotels Kitchen Generator'),
#                             ('StageName', 'Id. Decision Makers'),
#                             ('ExpectedRevenue', 9000.0),
#                             ('Amount', 15000.0),
#                             ('LeadSource', None),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 60.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9n0AAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Grand Hotels SLA'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 90000.0),
#                             ('Amount', 90000.0),
#                             ('LeadSource', 'External Referral'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9n1AAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name',
#                              'Express Logistics Portable Truck Generators'),
#                             ('StageName', 'Value Proposition'),
#                             ('ExpectedRevenue', 40000.0),
#                             ('Amount', 80000.0),
#                             ('LeadSource', 'External Referral'),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 50.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9n2AAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Express Logistics SLA'),
#                             ('StageName', 'Perception Analysis'),
#                             ('ExpectedRevenue', 84000.0),
#                             ('Amount', 120000.0),
#                             ('LeadSource', 'External Referral'),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 70.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9n3AAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Express Logistics Standby Generator'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 220000.0),
#                             ('Amount', 220000.0),
#                             ('LeadSource', 'Trade Show'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'New Customer'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9n4AAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'University of AZ Installations'),
#                             ('StageName', 'Proposal/Price Quote'),
#                             ('ExpectedRevenue', 75000.0),
#                             ('Amount', 100000.0),
#                             ('LeadSource', 'Employee Referral'),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 75.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9n5AAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'University of AZ Portable Generators'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 50000.0),
#                             ('Amount', 50000.0),
#                             ('LeadSource', 'Public Relations'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'New Customer'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9n6AAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'University of AZ SLA'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 90000.0),
#                             ('Amount', 90000.0),
#                             ('LeadSource', 'Public Relations'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9n7AAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'United Oil Emergency Generators'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 440000.0),
#                             ('Amount', 440000.0),
#                             ('LeadSource', 'External Referral'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9n8AAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'United Oil Installations'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 270000.0),
#                             ('Amount', 270000.0),
#                             ('LeadSource', 'Partner'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9n9AAA')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'United Oil Installations'),
#                             ('StageName', 'Negotiation/Review'),
#                             ('ExpectedRevenue', 243000.0),
#                             ('Amount', 270000.0),
#                             ('LeadSource', None),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 90.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nAAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'United Oil Office Portable Generators'),
#                             ('StageName', 'Negotiation/Review'),
#                             ('ExpectedRevenue', 112500.0),
#                             ('Amount', 125000.0),
#                             ('LeadSource', None),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 90.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nBAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'GenePoint Standby Generator'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 85000.0),
#                             ('Amount', 85000.0),
#                             ('LeadSource', 'Partner'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'New Customer'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nCAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name',
#                              'Burlington Textiles Weaving Plant Generator'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 235000.0),
#                             ('Amount', 235000.0),
#                             ('LeadSource', 'Web'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'New Customer'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nDAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'United Oil Installations'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 235000.0),
#                             ('Amount', 235000.0),
#                             ('LeadSource', 'External Referral'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nEAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'United Oil Plant Standby Generators'),
#                             ('StageName', 'Needs Analysis'),
#                             ('ExpectedRevenue', 135000.0),
#                             ('Amount', 675000.0),
#                             ('LeadSource', None),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 20.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nFAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'United Oil Refinery Generators'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 915000.0),
#                             ('Amount', 915000.0),
#                             ('LeadSource', 'Partner'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'New Customer'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nGAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'United Oil Refinery Generators'),
#                             ('StageName', 'Proposal/Price Quote'),
#                             ('ExpectedRevenue', 202500.0),
#                             ('Amount', 270000.0),
#                             ('LeadSource', None),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 75.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nHAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'United Oil SLA'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 120000.0),
#                             ('Amount', 120000.0),
#                             ('LeadSource', 'Partner'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nIAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'United Oil Standby Generators'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 120000.0),
#                             ('Amount', 120000.0),
#                             ('LeadSource', 'External Referral'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nJAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'GenePoint Lab Generators'),
#                             ('StageName', 'Id. Decision Makers'),
#                             ('ExpectedRevenue', 36000.0),
#                             ('Amount', 60000.0),
#                             ('LeadSource', None),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', None),
#                             ('Probability', 60.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nKAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'GenePoint SLA'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 30000.0),
#                             ('Amount', 30000.0),
#                             ('LeadSource', 'Partner'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nLAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Edge Emergency Generator'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 75000.0),
#                             ('Amount', 75000.0),
#                             ('LeadSource', 'Word of mouth'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'New Customer'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nMAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Edge Emergency Generator'),
#                             ('StageName', 'Id. Decision Makers'),
#                             ('ExpectedRevenue', 21000.0),
#                             ('Amount', 35000.0),
#                             ('LeadSource', None),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', 'Existing Customer - Replacement'),
#                             ('Probability', 60.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nNAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Edge Installation'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 50000.0),
#                             ('Amount', 50000.0),
#                             ('LeadSource', 'Word of mouth'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nOAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Pyramid Emergency Generators'),
#                             ('StageName', 'Prospecting'),
#                             ('ExpectedRevenue', 10000.0),
#                             ('Amount', 100000.0),
#                             ('LeadSource', 'Phone Inquiry'),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', None),
#                             ('Probability', 10.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nPAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Dickenson Mobile Generators'),
#                             ('StageName', 'Qualification'),
#                             ('ExpectedRevenue', 1500.0),
#                             ('Amount', 15000.0),
#                             ('LeadSource', 'Purchased List'),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', 'New Customer'),
#                             ('Probability', 10.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nQAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Grand Hotels Emergency Generators'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 210000.0),
#                             ('Amount', 210000.0),
#                             ('LeadSource', 'External Referral'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'New Customer'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nRAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Grand Hotels Generator Installations'),
#                             ('StageName', 'Closed Won'),
#                             ('ExpectedRevenue', 350000.0),
#                             ('Amount', 350000.0),
#                             ('LeadSource', 'External Referral'),
#                             ('IsWon', True),
#                             ('IsClosed', True),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 100.0)]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Opportunity'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Opportunity/00640000009m9nSAAQ')])),
#                             ('CreatedDate', '2008-04-24T11:43:09.000+0000'),
#                             ('Name', 'Grand Hotels Guest Portable Generators'),
#                             ('StageName', 'Value Proposition'),
#                             ('ExpectedRevenue', 125000.0),
#                             ('Amount', 250000.0),
#                             ('LeadSource', 'Employee Referral'),
#                             ('IsWon', False),
#                             ('IsClosed', False),
#                             ('Type', 'Existing Customer - Upgrade'),
#                             ('Probability', 50.0)])])])

# %%
import json
records=json.loads(opportunities.to_json(orient='records'))
records
# Out:
# [{'CreatedDate': '2008-04-24',
#   'Name': 'Edge SLA',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 60000.0,
#   'Amount': 60000.0,
#   'LeadSource': 'Word of mouth',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Grand Hotels Kitchen Generator',
#   'StageName': 'Id. Decision Makers',
#   'ExpectedRevenue': 9000.0,
#   'Amount': 15000.0,
#   'LeadSource': None,
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 60.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Grand Hotels SLA',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 90000.0,
#   'Amount': 90000.0,
#   'LeadSource': 'External Referral',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Express Logistics Portable Truck Generators',
#   'StageName': 'Value Proposition',
#   'ExpectedRevenue': 40000.0,
#   'Amount': 80000.0,
#   'LeadSource': 'External Referral',
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 50.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Express Logistics SLA',
#   'StageName': 'Perception Analysis',
#   'ExpectedRevenue': 84000.0,
#   'Amount': 120000.0,
#   'LeadSource': 'External Referral',
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 70.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Express Logistics Standby Generator',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 220000.0,
#   'Amount': 220000.0,
#   'LeadSource': 'Trade Show',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'New Customer',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'University of AZ Installations',
#   'StageName': 'Proposal/Price Quote',
#   'ExpectedRevenue': 75000.0,
#   'Amount': 100000.0,
#   'LeadSource': 'Employee Referral',
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 75.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'University of AZ Portable Generators',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 50000.0,
#   'Amount': 50000.0,
#   'LeadSource': 'Public Relations',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'New Customer',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'University of AZ SLA',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 90000.0,
#   'Amount': 90000.0,
#   'LeadSource': 'Public Relations',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'United Oil Emergency Generators',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 440000.0,
#   'Amount': 440000.0,
#   'LeadSource': 'External Referral',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'United Oil Installations',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 270000.0,
#   'Amount': 270000.0,
#   'LeadSource': 'Partner',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'United Oil Installations',
#   'StageName': 'Negotiation/Review',
#   'ExpectedRevenue': 243000.0,
#   'Amount': 270000.0,
#   'LeadSource': None,
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 90.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'United Oil Office Portable Generators',
#   'StageName': 'Negotiation/Review',
#   'ExpectedRevenue': 112500.0,
#   'Amount': 125000.0,
#   'LeadSource': None,
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 90.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'GenePoint Standby Generator',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 85000.0,
#   'Amount': 85000.0,
#   'LeadSource': 'Partner',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'New Customer',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Burlington Textiles Weaving Plant Generator',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 235000.0,
#   'Amount': 235000.0,
#   'LeadSource': 'Web',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'New Customer',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'United Oil Installations',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 235000.0,
#   'Amount': 235000.0,
#   'LeadSource': 'External Referral',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'United Oil Plant Standby Generators',
#   'StageName': 'Needs Analysis',
#   'ExpectedRevenue': 135000.0,
#   'Amount': 675000.0,
#   'LeadSource': None,
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 20.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'United Oil Refinery Generators',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 915000.0,
#   'Amount': 915000.0,
#   'LeadSource': 'Partner',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'New Customer',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'United Oil Refinery Generators',
#   'StageName': 'Proposal/Price Quote',
#   'ExpectedRevenue': 202500.0,
#   'Amount': 270000.0,
#   'LeadSource': None,
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 75.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'United Oil SLA',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 120000.0,
#   'Amount': 120000.0,
#   'LeadSource': 'Partner',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'United Oil Standby Generators',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 120000.0,
#   'Amount': 120000.0,
#   'LeadSource': 'External Referral',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'GenePoint Lab Generators',
#   'StageName': 'Id. Decision Makers',
#   'ExpectedRevenue': 36000.0,
#   'Amount': 60000.0,
#   'LeadSource': None,
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': None,
#   'Probability': 60.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'GenePoint SLA',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 30000.0,
#   'Amount': 30000.0,
#   'LeadSource': 'Partner',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Edge Emergency Generator',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 75000.0,
#   'Amount': 75000.0,
#   'LeadSource': 'Word of mouth',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'New Customer',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Edge Emergency Generator',
#   'StageName': 'Id. Decision Makers',
#   'ExpectedRevenue': 21000.0,
#   'Amount': 35000.0,
#   'LeadSource': None,
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': 'Existing Customer - Replacement',
#   'Probability': 60.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Edge Installation',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 50000.0,
#   'Amount': 50000.0,
#   'LeadSource': 'Word of mouth',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Pyramid Emergency Generators',
#   'StageName': 'Prospecting',
#   'ExpectedRevenue': 10000.0,
#   'Amount': 100000.0,
#   'LeadSource': 'Phone Inquiry',
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': None,
#   'Probability': 10.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Dickenson Mobile Generators',
#   'StageName': 'Qualification',
#   'ExpectedRevenue': 1500.0,
#   'Amount': 15000.0,
#   'LeadSource': 'Purchased List',
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': 'New Customer',
#   'Probability': 10.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Grand Hotels Emergency Generators',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 210000.0,
#   'Amount': 210000.0,
#   'LeadSource': 'External Referral',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'New Customer',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Grand Hotels Generator Installations',
#   'StageName': 'Closed Won',
#   'ExpectedRevenue': 350000.0,
#   'Amount': 350000.0,
#   'LeadSource': 'External Referral',
#   'IsWon': True,
#   'IsClosed': True,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 100.0},
#  {'CreatedDate': '2008-04-24',
#   'Name': 'Grand Hotels Guest Portable Generators',
#   'StageName': 'Value Proposition',
#   'ExpectedRevenue': 125000.0,
#   'Amount': 250000.0,
#   'LeadSource': 'Employee Referral',
#   'IsWon': False,
#   'IsClosed': False,
#   'Type': 'Existing Customer - Upgrade',
#   'Probability': 50.0}]

# %%
from sagas.conf.conf import cf
from pymongo import MongoClient
client = MongoClient(cf.ensure('mongo'))

# %%
db = client.salesforce
coll = db.opportunities
coll.insert_many(records)

# %%
cursor = db.opportunities.find({})
for rec in cursor:
    print(rec)
# Out:
# {'_id': ObjectId('5efc9fb0771e8a11070952f8'), 'CreatedDate': '2008-04-24', 'Name': 'Edge SLA', 'StageName': 'Closed Won', 'ExpectedRevenue': 60000.0, 'Amount': 60000.0, 'LeadSource': 'Word of mouth', 'IsWon': True, 'IsClosed': True, 'Type': 'Existing Customer - Upgrade', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a11070952f9'), 'CreatedDate': '2008-04-24', 'Name': 'Grand Hotels Kitchen Generator', 'StageName': 'Id. Decision Makers', 'ExpectedRevenue': 9000.0, 'Amount': 15000.0, 'LeadSource': None, 'IsWon': False, 'IsClosed': False, 'Type': 'Existing Customer - Upgrade', 'Probability': 60.0}
# {'_id': ObjectId('5efc9fb0771e8a11070952fa'), 'CreatedDate': '2008-04-24', 'Name': 'Grand Hotels SLA', 'StageName': 'Closed Won', 'ExpectedRevenue': 90000.0, 'Amount': 90000.0, 'LeadSource': 'External Referral', 'IsWon': True, 'IsClosed': True, 'Type': 'Existing Customer - Upgrade', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a11070952fb'), 'CreatedDate': '2008-04-24', 'Name': 'Express Logistics Portable Truck Generators', 'StageName': 'Value Proposition', 'ExpectedRevenue': 40000.0, 'Amount': 80000.0, 'LeadSource': 'External Referral', 'IsWon': False, 'IsClosed': False, 'Type': 'Existing Customer - Upgrade', 'Probability': 50.0}
# {'_id': ObjectId('5efc9fb0771e8a11070952fc'), 'CreatedDate': '2008-04-24', 'Name': 'Express Logistics SLA', 'StageName': 'Perception Analysis', 'ExpectedRevenue': 84000.0, 'Amount': 120000.0, 'LeadSource': 'External Referral', 'IsWon': False, 'IsClosed': False, 'Type': 'Existing Customer - Upgrade', 'Probability': 70.0}
# {'_id': ObjectId('5efc9fb0771e8a11070952fd'), 'CreatedDate': '2008-04-24', 'Name': 'Express Logistics Standby Generator', 'StageName': 'Closed Won', 'ExpectedRevenue': 220000.0, 'Amount': 220000.0, 'LeadSource': 'Trade Show', 'IsWon': True, 'IsClosed': True, 'Type': 'New Customer', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a11070952fe'), 'CreatedDate': '2008-04-24', 'Name': 'University of AZ Installations', 'StageName': 'Proposal/Price Quote', 'ExpectedRevenue': 75000.0, 'Amount': 100000.0, 'LeadSource': 'Employee Referral', 'IsWon': False, 'IsClosed': False, 'Type': 'Existing Customer - Upgrade', 'Probability': 75.0}
# {'_id': ObjectId('5efc9fb0771e8a11070952ff'), 'CreatedDate': '2008-04-24', 'Name': 'University of AZ Portable Generators', 'StageName': 'Closed Won', 'ExpectedRevenue': 50000.0, 'Amount': 50000.0, 'LeadSource': 'Public Relations', 'IsWon': True, 'IsClosed': True, 'Type': 'New Customer', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095300'), 'CreatedDate': '2008-04-24', 'Name': 'University of AZ SLA', 'StageName': 'Closed Won', 'ExpectedRevenue': 90000.0, 'Amount': 90000.0, 'LeadSource': 'Public Relations', 'IsWon': True, 'IsClosed': True, 'Type': 'Existing Customer - Upgrade', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095301'), 'CreatedDate': '2008-04-24', 'Name': 'United Oil Emergency Generators', 'StageName': 'Closed Won', 'ExpectedRevenue': 440000.0, 'Amount': 440000.0, 'LeadSource': 'External Referral', 'IsWon': True, 'IsClosed': True, 'Type': 'Existing Customer - Upgrade', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095302'), 'CreatedDate': '2008-04-24', 'Name': 'United Oil Installations', 'StageName': 'Closed Won', 'ExpectedRevenue': 270000.0, 'Amount': 270000.0, 'LeadSource': 'Partner', 'IsWon': True, 'IsClosed': True, 'Type': 'Existing Customer - Upgrade', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095303'), 'CreatedDate': '2008-04-24', 'Name': 'United Oil Installations', 'StageName': 'Negotiation/Review', 'ExpectedRevenue': 243000.0, 'Amount': 270000.0, 'LeadSource': None, 'IsWon': False, 'IsClosed': False, 'Type': 'Existing Customer - Upgrade', 'Probability': 90.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095304'), 'CreatedDate': '2008-04-24', 'Name': 'United Oil Office Portable Generators', 'StageName': 'Negotiation/Review', 'ExpectedRevenue': 112500.0, 'Amount': 125000.0, 'LeadSource': None, 'IsWon': False, 'IsClosed': False, 'Type': 'Existing Customer - Upgrade', 'Probability': 90.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095305'), 'CreatedDate': '2008-04-24', 'Name': 'GenePoint Standby Generator', 'StageName': 'Closed Won', 'ExpectedRevenue': 85000.0, 'Amount': 85000.0, 'LeadSource': 'Partner', 'IsWon': True, 'IsClosed': True, 'Type': 'New Customer', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095306'), 'CreatedDate': '2008-04-24', 'Name': 'Burlington Textiles Weaving Plant Generator', 'StageName': 'Closed Won', 'ExpectedRevenue': 235000.0, 'Amount': 235000.0, 'LeadSource': 'Web', 'IsWon': True, 'IsClosed': True, 'Type': 'New Customer', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095307'), 'CreatedDate': '2008-04-24', 'Name': 'United Oil Installations', 'StageName': 'Closed Won', 'ExpectedRevenue': 235000.0, 'Amount': 235000.0, 'LeadSource': 'External Referral', 'IsWon': True, 'IsClosed': True, 'Type': 'Existing Customer - Upgrade', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095308'), 'CreatedDate': '2008-04-24', 'Name': 'United Oil Plant Standby Generators', 'StageName': 'Needs Analysis', 'ExpectedRevenue': 135000.0, 'Amount': 675000.0, 'LeadSource': None, 'IsWon': False, 'IsClosed': False, 'Type': 'Existing Customer - Upgrade', 'Probability': 20.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095309'), 'CreatedDate': '2008-04-24', 'Name': 'United Oil Refinery Generators', 'StageName': 'Closed Won', 'ExpectedRevenue': 915000.0, 'Amount': 915000.0, 'LeadSource': 'Partner', 'IsWon': True, 'IsClosed': True, 'Type': 'New Customer', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a110709530a'), 'CreatedDate': '2008-04-24', 'Name': 'United Oil Refinery Generators', 'StageName': 'Proposal/Price Quote', 'ExpectedRevenue': 202500.0, 'Amount': 270000.0, 'LeadSource': None, 'IsWon': False, 'IsClosed': False, 'Type': 'Existing Customer - Upgrade', 'Probability': 75.0}
# {'_id': ObjectId('5efc9fb0771e8a110709530b'), 'CreatedDate': '2008-04-24', 'Name': 'United Oil SLA', 'StageName': 'Closed Won', 'ExpectedRevenue': 120000.0, 'Amount': 120000.0, 'LeadSource': 'Partner', 'IsWon': True, 'IsClosed': True, 'Type': 'Existing Customer - Upgrade', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a110709530c'), 'CreatedDate': '2008-04-24', 'Name': 'United Oil Standby Generators', 'StageName': 'Closed Won', 'ExpectedRevenue': 120000.0, 'Amount': 120000.0, 'LeadSource': 'External Referral', 'IsWon': True, 'IsClosed': True, 'Type': 'Existing Customer - Upgrade', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a110709530d'), 'CreatedDate': '2008-04-24', 'Name': 'GenePoint Lab Generators', 'StageName': 'Id. Decision Makers', 'ExpectedRevenue': 36000.0, 'Amount': 60000.0, 'LeadSource': None, 'IsWon': False, 'IsClosed': False, 'Type': None, 'Probability': 60.0}
# {'_id': ObjectId('5efc9fb0771e8a110709530e'), 'CreatedDate': '2008-04-24', 'Name': 'GenePoint SLA', 'StageName': 'Closed Won', 'ExpectedRevenue': 30000.0, 'Amount': 30000.0, 'LeadSource': 'Partner', 'IsWon': True, 'IsClosed': True, 'Type': 'Existing Customer - Upgrade', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a110709530f'), 'CreatedDate': '2008-04-24', 'Name': 'Edge Emergency Generator', 'StageName': 'Closed Won', 'ExpectedRevenue': 75000.0, 'Amount': 75000.0, 'LeadSource': 'Word of mouth', 'IsWon': True, 'IsClosed': True, 'Type': 'New Customer', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095310'), 'CreatedDate': '2008-04-24', 'Name': 'Edge Emergency Generator', 'StageName': 'Id. Decision Makers', 'ExpectedRevenue': 21000.0, 'Amount': 35000.0, 'LeadSource': None, 'IsWon': False, 'IsClosed': False, 'Type': 'Existing Customer - Replacement', 'Probability': 60.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095311'), 'CreatedDate': '2008-04-24', 'Name': 'Edge Installation', 'StageName': 'Closed Won', 'ExpectedRevenue': 50000.0, 'Amount': 50000.0, 'LeadSource': 'Word of mouth', 'IsWon': True, 'IsClosed': True, 'Type': 'Existing Customer - Upgrade', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095312'), 'CreatedDate': '2008-04-24', 'Name': 'Pyramid Emergency Generators', 'StageName': 'Prospecting', 'ExpectedRevenue': 10000.0, 'Amount': 100000.0, 'LeadSource': 'Phone Inquiry', 'IsWon': False, 'IsClosed': False, 'Type': None, 'Probability': 10.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095313'), 'CreatedDate': '2008-04-24', 'Name': 'Dickenson Mobile Generators', 'StageName': 'Qualification', 'ExpectedRevenue': 1500.0, 'Amount': 15000.0, 'LeadSource': 'Purchased List', 'IsWon': False, 'IsClosed': False, 'Type': 'New Customer', 'Probability': 10.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095314'), 'CreatedDate': '2008-04-24', 'Name': 'Grand Hotels Emergency Generators', 'StageName': 'Closed Won', 'ExpectedRevenue': 210000.0, 'Amount': 210000.0, 'LeadSource': 'External Referral', 'IsWon': True, 'IsClosed': True, 'Type': 'New Customer', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095315'), 'CreatedDate': '2008-04-24', 'Name': 'Grand Hotels Generator Installations', 'StageName': 'Closed Won', 'ExpectedRevenue': 350000.0, 'Amount': 350000.0, 'LeadSource': 'External Referral', 'IsWon': True, 'IsClosed': True, 'Type': 'Existing Customer - Upgrade', 'Probability': 100.0}
# {'_id': ObjectId('5efc9fb0771e8a1107095316'), 'CreatedDate': '2008-04-24', 'Name': 'Grand Hotels Guest Portable Generators', 'StageName': 'Value Proposition', 'ExpectedRevenue': 125000.0, 'Amount': 250000.0, 'LeadSource': 'Employee Referral', 'IsWon': False, 'IsClosed': False, 'Type': 'Existing Customer - Upgrade', 'Probability': 50.0}

# %%
import sagas
recs=[r for r in db.opportunities.find({})]
sagas.dict_df(recs)
# Out:
#                          _id CreatedDate  \
# 0   5efc9fb0771e8a11070952f8  2008-04-24
# 1   5efc9fb0771e8a11070952f9  2008-04-24
# 2   5efc9fb0771e8a11070952fa  2008-04-24
# 3   5efc9fb0771e8a11070952fb  2008-04-24
# 4   5efc9fb0771e8a11070952fc  2008-04-24
# 5   5efc9fb0771e8a11070952fd  2008-04-24
# 6   5efc9fb0771e8a11070952fe  2008-04-24
# 7   5efc9fb0771e8a11070952ff  2008-04-24
# 8   5efc9fb0771e8a1107095300  2008-04-24
# 9   5efc9fb0771e8a1107095301  2008-04-24
# 10  5efc9fb0771e8a1107095302  2008-04-24
# 11  5efc9fb0771e8a1107095303  2008-04-24
# 12  5efc9fb0771e8a1107095304  2008-04-24
# 13  5efc9fb0771e8a1107095305  2008-04-24
# 14  5efc9fb0771e8a1107095306  2008-04-24
# 15  5efc9fb0771e8a1107095307  2008-04-24
# 16  5efc9fb0771e8a1107095308  2008-04-24
# 17  5efc9fb0771e8a1107095309  2008-04-24
# 18  5efc9fb0771e8a110709530a  2008-04-24
# 19  5efc9fb0771e8a110709530b  2008-04-24
# 20  5efc9fb0771e8a110709530c  2008-04-24
# 21  5efc9fb0771e8a110709530d  2008-04-24
# 22  5efc9fb0771e8a110709530e  2008-04-24
# 23  5efc9fb0771e8a110709530f  2008-04-24
# 24  5efc9fb0771e8a1107095310  2008-04-24
# 25  5efc9fb0771e8a1107095311  2008-04-24
# 26  5efc9fb0771e8a1107095312  2008-04-24
# 27  5efc9fb0771e8a1107095313  2008-04-24
# 28  5efc9fb0771e8a1107095314  2008-04-24
# 29  5efc9fb0771e8a1107095315  2008-04-24
# 30  5efc9fb0771e8a1107095316  2008-04-24
#
#                                            Name             StageName  \
# 0                                      Edge SLA            Closed Won
# 1                Grand Hotels Kitchen Generator   Id. Decision Makers
# 2                              Grand Hotels SLA            Closed Won
# 3   Express Logistics Portable Truck Generators     Value Proposition
# 4                         Express Logistics SLA   Perception Analysis
# 5           Express Logistics Standby Generator            Closed Won
# 6                University of AZ Installations  Proposal/Price Quote
# 7          University of AZ Portable Generators            Closed Won
# 8                          University of AZ SLA            Closed Won
# 9               United Oil Emergency Generators            Closed Won
# 10                     United Oil Installations            Closed Won
# 11                     United Oil Installations    Negotiation/Review
# 12        United Oil Office Portable Generators    Negotiation/Review
# 13                  GenePoint Standby Generator            Closed Won
# 14  Burlington Textiles Weaving Plant Generator            Closed Won
# 15                     United Oil Installations            Closed Won
# 16          United Oil Plant Standby Generators        Needs Analysis
# 17               United Oil Refinery Generators            Closed Won
# 18               United Oil Refinery Generators  Proposal/Price Quote
# 19                               United Oil SLA            Closed Won
# 20                United Oil Standby Generators            Closed Won
# 21                     GenePoint Lab Generators   Id. Decision Makers
# 22                                GenePoint SLA            Closed Won
# 23                     Edge Emergency Generator            Closed Won
# 24                     Edge Emergency Generator   Id. Decision Makers
# 25                            Edge Installation            Closed Won
# 26                 Pyramid Emergency Generators           Prospecting
# 27                  Dickenson Mobile Generators         Qualification
# 28            Grand Hotels Emergency Generators            Closed Won
# 29         Grand Hotels Generator Installations            Closed Won
# 30       Grand Hotels Guest Portable Generators     Value Proposition
#
#     ExpectedRevenue    Amount         LeadSource  IsWon  IsClosed  \
# 0           60000.0   60000.0      Word of mouth   True      True
# 1            9000.0   15000.0               None  False     False
# 2           90000.0   90000.0  External Referral   True      True
# 3           40000.0   80000.0  External Referral  False     False
# 4           84000.0  120000.0  External Referral  False     False
# 5          220000.0  220000.0         Trade Show   True      True
# 6           75000.0  100000.0  Employee Referral  False     False
# 7           50000.0   50000.0   Public Relations   True      True
# 8           90000.0   90000.0   Public Relations   True      True
# 9          440000.0  440000.0  External Referral   True      True
# 10         270000.0  270000.0            Partner   True      True
# 11         243000.0  270000.0               None  False     False
# 12         112500.0  125000.0               None  False     False
# 13          85000.0   85000.0            Partner   True      True
# 14         235000.0  235000.0                Web   True      True
# 15         235000.0  235000.0  External Referral   True      True
# 16         135000.0  675000.0               None  False     False
# 17         915000.0  915000.0            Partner   True      True
# 18         202500.0  270000.0               None  False     False
# 19         120000.0  120000.0            Partner   True      True
# 20         120000.0  120000.0  External Referral   True      True
# 21          36000.0   60000.0               None  False     False
# 22          30000.0   30000.0            Partner   True      True
# 23          75000.0   75000.0      Word of mouth   True      True
# 24          21000.0   35000.0               None  False     False
# 25          50000.0   50000.0      Word of mouth   True      True
# 26          10000.0  100000.0      Phone Inquiry  False     False
# 27           1500.0   15000.0     Purchased List  False     False
# 28         210000.0  210000.0  External Referral   True      True
# 29         350000.0  350000.0  External Referral   True      True
# 30         125000.0  250000.0  Employee Referral  False     False
#
#                                Type  Probability
# 0       Existing Customer - Upgrade        100.0
# 1       Existing Customer - Upgrade         60.0
# 2       Existing Customer - Upgrade        100.0
# 3       Existing Customer - Upgrade         50.0
# 4       Existing Customer - Upgrade         70.0
# 5                      New Customer        100.0
# 6       Existing Customer - Upgrade         75.0
# 7                      New Customer        100.0
# 8       Existing Customer - Upgrade        100.0
# 9       Existing Customer - Upgrade        100.0
# 10      Existing Customer - Upgrade        100.0
# 11      Existing Customer - Upgrade         90.0
# 12      Existing Customer - Upgrade         90.0
# 13                     New Customer        100.0
# 14                     New Customer        100.0
# 15      Existing Customer - Upgrade        100.0
# 16      Existing Customer - Upgrade         20.0
# 17                     New Customer        100.0
# 18      Existing Customer - Upgrade         75.0
# 19      Existing Customer - Upgrade        100.0
# 20      Existing Customer - Upgrade        100.0
# 21                             None         60.0
# 22      Existing Customer - Upgrade        100.0
# 23                     New Customer        100.0
# 24  Existing Customer - Replacement         60.0
# 25      Existing Customer - Upgrade        100.0
# 26                             None         10.0
# 27                     New Customer         10.0
# 28                     New Customer        100.0
# 29      Existing Customer - Upgrade        100.0
# 30      Existing Customer - Upgrade         50.0

# %%
sf_manager.login()
client=sf_manager.sf
client.query('SELECT ID FROM Account')
# Out:
# OrderedDict([('totalSize', 13),
#              ('done', True),
#              ('records',
#               [OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzQAAV')])),
#                             ('Id', '0014000000HaKzQAAV')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzRAAV')])),
#                             ('Id', '0014000000HaKzRAAV')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzSAAV')])),
#                             ('Id', '0014000000HaKzSAAV')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzTAAV')])),
#                             ('Id', '0014000000HaKzTAAV')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzUAAV')])),
#                             ('Id', '0014000000HaKzUAAV')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzVAAV')])),
#                             ('Id', '0014000000HaKzVAAV')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzWAAV')])),
#                             ('Id', '0014000000HaKzWAAV')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzXAAV')])),
#                             ('Id', '0014000000HaKzXAAV')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzYAAV')])),
#                             ('Id', '0014000000HaKzYAAV')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzZAAV')])),
#                             ('Id', '0014000000HaKzZAAV')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzaAAF')])),
#                             ('Id', '0014000000HaKzaAAF')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HaKzbAAF')])),
#                             ('Id', '0014000000HaKzbAAF')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Account'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Account/0014000000HabN6AAJ')])),
#                             ('Id', '0014000000HabN6AAJ')])])])
