# %%
from sagas.ofbiz.services import OfService as s, oc, track
ok, r=track(lambda a: s().testScv(defaultValue=5.5, message="hello world"))
print(ok, r)
# Out:
# ✔ testScv default 21 2019-02-11 01:59:05.807 ➷ 4 ms
# True {'responseMessage': 'success', 'resp': 'service done'}

# %%
from sagas.ofbiz.services import OfService as s, oc, track
import sagas.ofbiz.entities as ee
from sagas.ofbiz.entities import OfEntity as e

# this is Deprecated service
ok,r=s().findParty(partyId='DemoCustomer',
    roleTypeId='CUSTOMER')
for el in r:
    print(el)
print(r['partyListSize'])
rs=r['partyList']
ee.record_list_df("Party", rs)
# Out:
# viewSize
# lowIndex
# partyTypes
# paramList
# viewIndex
# currentRole
# highIndex
# responseMessage
# partyList
# roleTypes
# partyListSize
# 0
# Empty DataFrame
# Columns: []
# Index: []

# %%
ok,r=s().findParty(partyId='TestCustomer',
    roleTypeId='CUSTOMER')
ee.record_list_df("Party", r['partyList'])
# Out:
# Empty DataFrame
# Columns: [lastUpdatedStamp, createdTxStamp, createdStamp, externalId, description, lastUpdatedTxStamp, isUnread, partyTypeId, lastModifiedByUserLogin, dataSourceId, createdDate, statusId, preferredCurrencyUomId, partyId, createdByUserLogin]
# Index: []

# %%
ee.record_list_df("PartyType", r['partyTypes'])
# Out:
#           partyTypeId        lastUpdatedStamp        parentTypeId hasTable  \
# 0     AUTOMATED_AGENT 2019-01-26 21:09:06.992                None        N
# 1         CORPORATION 2019-01-26 21:09:07.001  LEGAL_ORGANIZATION        N
# 2              FAMILY 2019-01-26 21:09:06.996      INFORMAL_GROUP        N
# 3   GOVERNMENT_AGENCY 2019-01-26 21:09:07.002  LEGAL_ORGANIZATION        N
# 4      INFORMAL_GROUP 2019-01-26 21:09:06.995         PARTY_GROUP        N
# 5  LEGAL_ORGANIZATION 2019-01-26 21:09:07.000         PARTY_GROUP        N
# 6         PARTY_GROUP 2019-01-26 21:09:06.994                None        Y
# 7              PERSON 2019-01-26 21:09:06.993                None        Y
# 8                TEAM 2019-01-26 21:09:06.998      INFORMAL_GROUP        N
#
#            createdTxStamp            createdStamp         description  \
# 0 2019-01-26 21:09:06.718 2019-01-26 21:09:06.992     Automated Agent
# 1 2019-01-26 21:09:06.718 2019-01-26 21:09:07.001         Corporation
# 2 2019-01-26 21:09:06.718 2019-01-26 21:09:06.996              Family
# 3 2019-01-26 21:09:06.718 2019-01-26 21:09:07.002   Government Agency
# 4 2019-01-26 21:09:06.718 2019-01-26 21:09:06.995      Informal Group
# 5 2019-01-26 21:09:06.718 2019-01-26 21:09:07.000  Legal Organization
# 6 2019-01-26 21:09:06.718 2019-01-26 21:09:06.994         Party Group
# 7 2019-01-26 21:09:06.718 2019-01-26 21:09:06.993              Person
# 8 2019-01-26 21:09:06.718 2019-01-26 21:09:06.998                Team
#
#        lastUpdatedTxStamp
# 0 2019-01-26 21:09:06.718
# 1 2019-01-26 21:09:06.718
# 2 2019-01-26 21:09:06.718
# 3 2019-01-26 21:09:06.718
# 4 2019-01-26 21:09:06.718
# 5 2019-01-26 21:09:06.718
# 6 2019-01-26 21:09:06.718
# 7 2019-01-26 21:09:06.718
# 8 2019-01-26 21:09:06.718

# %%
import sagas.ofbiz.entities as ee
from sagas.ofbiz.entities import OfEntity as e

df=e('df').allPartyRoleDetailAndPartyDetail()
# df.info()
# df=df.dropna(axis=1,how='all') 
df
# Out:
#      partyTypeId hasTable preferredCurrencyUomId             partyId  \
# 0    PARTY_GROUP        N                   None    accountant_group
# 1    PARTY_GROUP        N                   None    accountant_group
# 2    PARTY_GROUP        N                   None          ACCOUNTING
# 3    PARTY_GROUP        Y                   None          ACCOUNTING
# 4    PARTY_GROUP        N                   None          ACCOUNTING
# 5         PERSON        N                   None     accountingadmin
# 6         PERSON        N                   None     accountingadmin
# 7         PERSON        N                   None     accountingadmin
# 8    PARTY_GROUP        N                   None     AcctBigSupplier
# 9         PERSON        N                   None           AcctBuyer
# 10        PERSON        N                   None               admin
# 11        PERSON     None                   None               admin
# 12        PERSON        N                   None               admin
# 13        PERSON        N                   None               admin
# 14        PERSON        N                   None               admin
# 15        PERSON        N                   None               admin
# 16        PERSON        N                   None               admin
# 17        PERSON        N                   None               admin
# 18        PERSON        N                   None               admin
# 19        PERSON        N                   None               admin
# 20        PERSON        N                   None               admin
# 21        PERSON        N                   None               admin
# 22        PERSON        N                   None               admin
# 23        PERSON        N                   None               admin
# 24   PARTY_GROUP        N                   None             anz_div
# 25   PARTY_GROUP        Y                   None             anz_div
# 26        PERSON     None                   None            approver
# 27        PERSON     None                   None            approver
# 28   PARTY_GROUP        N                   None            asia_div
# 29   PARTY_GROUP        Y                   None            asia_div
# ..           ...      ...                    ...                 ...
# 227  PARTY_GROUP        N                   None         TestCompany
# 228       PERSON        N                   None        TestCustomer
# 229       PERSON        N                   None        TestCustomer
# 230       PERSON        N                   None        TestCustomer
# 231  PARTY_GROUP        Y                   None             TESTING
# 232  PARTY_GROUP        N                   None             TESTING
# 233  PARTY_GROUP        Y                   None        TestingTeam1
# 234  PARTY_GROUP        N                   None        TestingTeam1
# 235  PARTY_GROUP        Y                   None        TestingTeam2
# 236  PARTY_GROUP        N                   None        TestingTeam2
# 237       PERSON        N                   None  TestingTeamMember1
# 238       PERSON        N                   None  TestingTeamMember1
# 239       PERSON        N                   None  TestingTeamMember1
# 240       PERSON        N                   None  TestingTeamMember2
# 241       PERSON        N                   None  TestingTeamMember2
# 242       PERSON        N                   None  TestingTeamMember3
# 243       PERSON        N                   None  TestingTeamMember3
# 244       PERSON        N                   None           TestParty
# 245  PARTY_GROUP        N                   None           TX_TAXMAN
# 246  PARTY_GROUP        N                   None                 UPS
# 247  PARTY_GROUP        N                   None             USA_IRS
# 248  PARTY_GROUP        N                   None                USPS
# 249  PARTY_GROUP        N                   None           UT_TAXMAN
# 250  PARTY_GROUP        N                   None      UT_UTAH_TAXMAN
# 251  PARTY_GROUP        N                   None              we_div
# 252  PARTY_GROUP        Y                   None              we_div
# 253  PARTY_GROUP        N                   None          widget_div
# 254  PARTY_GROUP        Y                   None          widget_div
# 255       PERSON        N                   None                _NA_
# 256       PERSON        N                   None                _NA_
#
#     createdByUserLogin logoImageUrl           firstName  \
# 0                 None         None                None
# 1                 None         None                None
# 2                admin         None                None
# 3                admin         None                None
# 4                admin         None                None
# 5                 None         None          Accounting
# 6                 None         None          Accounting
# 7                 None         None          Accounting
# 8                 None         None                None
# 9                 None         None                Acct
# 10                None         None                 THE
# 11                None         None                 THE
# 12                None         None                 THE
# 13                None         None                 THE
# 14                None         None                 THE
# 15                None         None                 THE
# 16                None         None                 THE
# 17                None         None                 THE
# 18                None         None                 THE
# 19                None         None                 THE
# 20                None         None                 THE
# 21                None         None                 THE
# 22                None         None                 THE
# 23                None         None                 THE
# 24                None         None                None
# 25                None         None                None
# 26                None         None              Robert
# 27                None         None              Robert
# 28                None         None                None
# 29                None         None                None
# ..                 ...          ...                 ...
# 227               None         None                None
# 228               None         None                Test
# 229               None         None                Test
# 230               None         None                Test
# 231              admin         None                None
# 232              admin         None                None
# 233              admin         None                None
# 234              admin         None                None
# 235              admin         None                None
# 236              admin         None                None
# 237               None         None  TestingTeamMember1
# 238               None         None  TestingTeamMember1
# 239               None         None  TestingTeamMember1
# 240               None         None  TestingTeamMember2
# 241               None         None  TestingTeamMember2
# 242               None         None  TestingTeamMember3
# 243               None         None  TestingTeamMember3
# 244               None         None                Test
# 245               None         None                None
# 246               None         None                None
# 247               None         None                None
# 248               None         None                None
# 249               None         None                None
# 250               None         None                None
# 251               None         None                None
# 252               None         None                None
# 253               None         None                None
# 254               None         None                None
# 255               None         None                None
# 256               None         None                None
#
#                                              groupName       statusId  \
# 0                                     Accountant Group  PARTY_ENABLED
# 1                                     Accountant Group  PARTY_ENABLED
# 2                                Accounting department  PARTY_ENABLED
# 3                                Accounting department  PARTY_ENABLED
# 4                                Accounting department  PARTY_ENABLED
# 5                                                 None  PARTY_ENABLED
# 6                                                 None  PARTY_ENABLED
# 7                                                 None  PARTY_ENABLED
# 8                                    Acct Big Supplier           None
# 9                                                 None           None
# 10                                                None  PARTY_ENABLED
# 11                                                None  PARTY_ENABLED
# 12                                                None  PARTY_ENABLED
# 13                                                None  PARTY_ENABLED
# 14                                                None  PARTY_ENABLED
# 15                                                None  PARTY_ENABLED
# 16                                                None  PARTY_ENABLED
# 17                                                None  PARTY_ENABLED
# 18                                                None  PARTY_ENABLED
# 19                                                None  PARTY_ENABLED
# 20                                                None  PARTY_ENABLED
# 21                                                None  PARTY_ENABLED
# 22                                                None  PARTY_ENABLED
# 23                                                None  PARTY_ENABLED
# 24                           Australia and New Zealand  PARTY_ENABLED
# 25                           Australia and New Zealand  PARTY_ENABLED
# 26                                                None  PARTY_ENABLED
# 27                                                None  PARTY_ENABLED
# 28                                                Asia  PARTY_ENABLED
# 29                                                Asia  PARTY_ENABLED
# ..                                                 ...            ...
# 227                             Your Company Name Here  PARTY_ENABLED
# 228                                               None  PARTY_ENABLED
# 229                                               None  PARTY_ENABLED
# 230                                               None  PARTY_ENABLED
# 231                                 Testing department  PARTY_ENABLED
# 232                                 Testing department  PARTY_ENABLED
# 233                                      Testing Team1  PARTY_ENABLED
# 234                                      Testing Team1  PARTY_ENABLED
# 235                                      Testing Team2  PARTY_ENABLED
# 236                                      Testing Team2  PARTY_ENABLED
# 237                                               None  PARTY_ENABLED
# 238                                               None  PARTY_ENABLED
# 239                                               None  PARTY_ENABLED
# 240                                               None  PARTY_ENABLED
# 241                                               None  PARTY_ENABLED
# 242                                               None  PARTY_ENABLED
# 243                                               None  PARTY_ENABLED
# 244                                               None  PARTY_ENABLED
# 245                          Texas Sales Tax Authority           None
# 246                                                UPS           None
# 247  United States of America - Internal Revenue Se...           None
# 248                                               USPS           None
# 249                           Utah Sales Tax Authority           None
# 250              Utah County, Utah Sales Tax Authority           None
# 251                                     Western Europe  PARTY_ENABLED
# 252                                     Western Europe  PARTY_ENABLED
# 253                               Widget Business Unit  PARTY_ENABLED
# 254                               Widget Business Unit  PARTY_ENABLED
# 255                                               None  PARTY_ENABLED
# 256                                               None  PARTY_ENABLED
#
#           lastName            description lastModifiedByUserLogin  \
# 0             None           Organization                    None
# 1             None         Not Applicable                    None
# 2             None             Department                   admin
# 3             None  Internal Organization                   admin
# 4             None         Not Applicable                   admin
# 5    Administrator             Accountant                    None
# 6    Administrator               Employee                    None
# 7    Administrator         Not Applicable                    None
# 8             None               Supplier                    None
# 9            Buyer                  Buyer                    None
# 10   ADMINISTRATOR              Addressee                    None
# 11   ADMINISTRATOR               Approver                    None
# 12   ADMINISTRATOR                  Buyer                    None
# 13   ADMINISTRATOR      Calendar Attendee                    None
# 14   ADMINISTRATOR         Calendar Owner                    None
# 15   ADMINISTRATOR                Contact                    None
# 16   ADMINISTRATOR    Email Administrator                    None
# 17   ADMINISTRATOR         Image Approver                    None
# 18   ADMINISTRATOR                Manager                    None
# 19   ADMINISTRATOR            Order Clerk                    None
# 20   ADMINISTRATOR          Request Taker                    None
# 21   ADMINISTRATOR   Sales Representative                    None
# 22   ADMINISTRATOR         Shipment Clerk                    None
# 23   ADMINISTRATOR         Not Applicable                    None
# 24            None               Division                    None
# 25            None  Internal Organization                    None
# 26           Smith               Approver                    None
# 27           Smith               Reviewer                    None
# 28            None               Division                    None
# 29            None  Internal Organization                    None
# ..             ...                    ...                     ...
# 227           None         Not Applicable                    None
# 228       Customer             Accountant                    None
# 229       Customer                Contact                    None
# 230       Customer               Customer                    None
# 231           None  Internal Organization                   admin
# 232           None         Not Applicable                   admin
# 233           None  Internal Organization                   admin
# 234           None         Not Applicable                   admin
# 235           None  Internal Organization                   admin
# 236           None         Not Applicable                   admin
# 237           None               Employee                    None
# 238           None                Manager                    None
# 239           None         Not Applicable                    None
# 240           None               Employee                    None
# 241           None         Not Applicable                    None
# 242           None               Employee                    None
# 243           None         Not Applicable                    None
# 244          Party                Contact                    None
# 245           None          Tax Authority                    None
# 246           None                Carrier                    None
# 247           None          Tax Authority                    None
# 248           None                Carrier                    None
# 249           None          Tax Authority                    None
# 250           None          Tax Authority                    None
# 251           None               Division                    None
# 252           None  Internal Organization                    None
# 253           None               Division                    None
# 254           None  Internal Organization                    None
# 255           None                Carrier                    None
# 256           None         Not Applicable                    None
#
#                roleTypeId       parentTypeId             createdDate  \
# 0       ORGANIZATION_ROLE          MAIN_ROLE                     NaT
# 1                    _NA_               None                     NaT
# 2              DEPARTMENT  ORGANIZATION_UNIT 2004-03-27 09:37:40.989
# 3    INTERNAL_ORGANIZATIO  ORGANIZATION_ROLE 2004-03-27 09:37:40.989
# 4                    _NA_               None 2004-03-27 09:37:40.989
# 5              ACCOUNTANT               None                     NaT
# 6                EMPLOYEE        PERSON_ROLE                     NaT
# 7                    _NA_               None                     NaT
# 8                SUPPLIER  ORGANIZATION_ROLE                     NaT
# 9                   BUYER           EMPLOYEE                     NaT
# 10              ADDRESSEE     COMMEVENT_ROLE                     NaT
# 11               APPROVER               None                     NaT
# 12                  BUYER           EMPLOYEE                     NaT
# 13           CAL_ATTENDEE      CALENDAR_ROLE                     NaT
# 14              CAL_OWNER      CALENDAR_ROLE                     NaT
# 15                CONTACT           SFA_ROLE                     NaT
# 16            EMAIL_ADMIN        PERSON_ROLE                     NaT
# 17          IMAGEAPPROVER               None                     NaT
# 18                MANAGER           EMPLOYEE                     NaT
# 19            ORDER_CLERK           EMPLOYEE                     NaT
# 20              REQ_TAKER       REQUEST_ROLE                     NaT
# 21              SALES_REP        PERSON_ROLE                     NaT
# 22         SHIPMENT_CLERK           EMPLOYEE                     NaT
# 23                   _NA_               None                     NaT
# 24               DIVISION  ORGANIZATION_UNIT                     NaT
# 25   INTERNAL_ORGANIZATIO  ORGANIZATION_ROLE                     NaT
# 26               APPROVER               None                     NaT
# 27               REVIEWER               None                     NaT
# 28               DIVISION  ORGANIZATION_UNIT                     NaT
# 29   INTERNAL_ORGANIZATIO  ORGANIZATION_ROLE                     NaT
# ..                    ...                ...                     ...
# 227                  _NA_               None                     NaT
# 228            ACCOUNTANT               None                     NaT
# 229               CONTACT           SFA_ROLE                     NaT
# 230              CUSTOMER               None                     NaT
# 231  INTERNAL_ORGANIZATIO  ORGANIZATION_ROLE 2004-03-27 09:37:40.989
# 232                  _NA_               None 2004-03-27 09:37:40.989
# 233  INTERNAL_ORGANIZATIO  ORGANIZATION_ROLE 2009-05-06 11:16:40.989
# 234                  _NA_               None 2009-05-06 11:16:40.989
# 235  INTERNAL_ORGANIZATIO  ORGANIZATION_ROLE 2009-05-06 11:16:40.989
# 236                  _NA_               None 2009-05-06 11:16:40.989
# 237              EMPLOYEE        PERSON_ROLE                     NaT
# 238               MANAGER           EMPLOYEE                     NaT
# 239                  _NA_               None                     NaT
# 240              EMPLOYEE        PERSON_ROLE                     NaT
# 241                  _NA_               None                     NaT
# 242              EMPLOYEE        PERSON_ROLE                     NaT
# 243                  _NA_               None                     NaT
# 244               CONTACT           SFA_ROLE                     NaT
# 245         TAX_AUTHORITY  ORGANIZATION_ROLE                     NaT
# 246               CARRIER  ORGANIZATION_ROLE                     NaT
# 247         TAX_AUTHORITY  ORGANIZATION_ROLE                     NaT
# 248               CARRIER  ORGANIZATION_ROLE                     NaT
# 249         TAX_AUTHORITY  ORGANIZATION_ROLE                     NaT
# 250         TAX_AUTHORITY  ORGANIZATION_ROLE                     NaT
# 251              DIVISION  ORGANIZATION_UNIT                     NaT
# 252  INTERNAL_ORGANIZATIO  ORGANIZATION_ROLE                     NaT
# 253              DIVISION  ORGANIZATION_UNIT                     NaT
# 254  INTERNAL_ORGANIZATIO  ORGANIZATION_ROLE                     NaT
# 255               CARRIER  ORGANIZATION_ROLE                     NaT
# 256                  _NA_               None                     NaT
#
#      middleName personalTitle
# 0          None          None
# 1          None          None
# 2          None          None
# 3          None          None
# 4          None          None
# 5          None          None
# 6          None          None
# 7          None          None
# 8          None          None
# 9          None          None
# 10   PRIVILEGED           Mr.
# 11   PRIVILEGED           Mr.
# 12   PRIVILEGED           Mr.
# 13   PRIVILEGED           Mr.
# 14   PRIVILEGED           Mr.
# 15   PRIVILEGED           Mr.
# 16   PRIVILEGED           Mr.
# 17   PRIVILEGED           Mr.
# 18   PRIVILEGED           Mr.
# 19   PRIVILEGED           Mr.
# 20   PRIVILEGED           Mr.
# 21   PRIVILEGED           Mr.
# 22   PRIVILEGED           Mr.
# 23   PRIVILEGED           Mr.
# 24         None          None
# 25         None          None
# 26         None       Captain
# 27         None       Captain
# 28         None          None
# 29         None          None
# ..          ...           ...
# 227        None          None
# 228        None          None
# 229        None          None
# 230        None          None
# 231        None          None
# 232        None          None
# 233        None          None
# 234        None          None
# 235        None          None
# 236        None          None
# 237        None          None
# 238        None          None
# 239        None          None
# 240        None          None
# 241        None          None
# 242        None          None
# 243        None          None
# 244        None          None
# 245        None          None
# 246        None          None
# 247        None          None
# 248        None          None
# 249        None          None
# 250        None          None
# 251        None          None
# 252        None          None
# 253        None          None
# 254        None          None
# 255        None          None
# 256        None          None
#
# [257 rows x 17 columns]

# %%
e('df').queryPartyRoleDetailAndPartyDetail(partyId='DemoCustomer',
    roleTypeId='CUSTOMER')
# Out:
#   partyTypeId hasTable       partyId firstName       statusId  lastName  \
# 0      PERSON        N  DemoCustomer      Demo  PARTY_ENABLED  Customer
#
#   description roleTypeId
# 0    Customer   CUSTOMER
