# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
matplotlib.style.use('ggplot')#使用ggplot样式
# %matplotlib inline

# %%
from sagas.ofbiz.entities import oc,finder,OfEntity, MetaEntity
from sagas.ofbiz.services import OfService
OfEntity().getProductType(productTypeId="Test_type_2")
# Out:
# {'lastUpdatedStamp': JavaObject id=o38, 'isPhysical': None, 'parentTypeId': None, 'isDigital': None, 'hasTable': None, 'createdTxStamp': JavaObject id=o39, 'createdStamp': JavaObject id=o40, 'description': None, 'lastUpdatedTxStamp': JavaObject id=o41, 'productTypeId': 'Test_type_2'}

# %% [markdown]
# ```xml
# <ProductPrice productId="DemoProduct-1" productPricePurposeId="PURCHASE" productPriceTypeId="DEFAULT_PRICE" currencyUomId="USD" productStoreGroupId="_NA_" fromDate="2006-05-13 12:00:00.0" price="15.00" createdDate="2006-05-13 12:00:00.0"  lastModifiedDate="2006-05-13 12:00:00.0"/>
# ```

# %%
import pyarrow as pa

records=OfEntity().listProductPrice()
products=[]
price_purposes=[]
price_types=[]
prices=[]

for rec in records:
    type_id=rec['productPriceTypeId']
    if type_id=="DEFAULT_PRICE":
        products.append(rec['productId'])
        price_purposes.append(rec['productPricePurposeId'])
        price_types.append(type_id)
        prices.append(float(rec['price']))

data = [
    pa.array(products),
    pa.array(price_purposes),
    pa.array(price_types),
    pa.array(prices)
]
batch = pa.RecordBatch.from_arrays(data, ['product', 'purpose', 'type', 'price'])
batches = [batch] 
table = pa.Table.from_batches(batches)
print(table, table.num_rows, table.num_columns)
# Out:
# pyarrow.Table
# product: string
# purpose: string
# type: string
# price: double 8 4

# %%
tables = [table] 
table_all = pa.concat_tables(tables)
print(table_all.num_rows)

df_new = table_all.to_pandas()
# df_new.head()
df_new[:20]
# Out:
# 8
#          product          purpose           type   price
# 0  BoatRowSimple         PURCHASE  DEFAULT_PRICE  549.99
# 1            Cap         PURCHASE  DEFAULT_PRICE    5.99
# 2       CFSV1001         PURCHASE  DEFAULT_PRICE    9.99
# 3        CPU-586  COMPONENT_PRICE  DEFAULT_PRICE  250.00
# 4  DemoProduct-1         PURCHASE  DEFAULT_PRICE   15.00
# 5  DemoProduct-2         PURCHASE  DEFAULT_PRICE    5.00
# 6  DemoProduct-3         PURCHASE  DEFAULT_PRICE   10.00
# 7          DOUGH  COMPONENT_PRICE  DEFAULT_PRICE    3.00

# %%
df_new.iloc[3]
# Out:
# product            CPU-586
# purpose    COMPONENT_PRICE
# type         DEFAULT_PRICE
# price              250.000
# Name: 3, dtype: object

# %%
df_new['price']
# Out:
# 0    549.990
# 1      5.990
# 2      9.990
# 3    250.000
# 4     15.000
# 5      5.000
# 6     10.000
# 7      3.000
# Name: price, dtype: object

# %%
plt.figure();
# df_new['price'].plot.hist(orientation='horizontal', cumulative=True)
df_new['price'].plot.hist(orientation='horizontal', cumulative=False)

# %%
plt.figure()
df_new['price'].plot.hist(alpha=0.8)

# %%
product=MetaEntity("Product").record("GZ-2002")
ok, ret=OfService().calculateProductPrice(product=product)
print(ret['defaultPrice'], ret['listPrice'])
print(ret)
# Out:
# 47.990 48.000
# {'defaultPrice': Decimal('47.990'), 'currencyUsed': 'USD', 'price': Decimal('47.990'), 'orderItemPriceInfos': [], 'specialPromoPrice': None, 'isSale': False, 'validPriceFound': True, 'averageCost': Decimal('48.000'), 'competitivePrice': None, 'listPrice': Decimal('48.000'), 'basePrice': Decimal('47.990')}

# %%
def get_product_price(product_id):
    product=MetaEntity("Product").record(product_id)
    ok, ret=OfService().calculateProductPrice(product=product)
    return ret
def pickup(record, fields):
    result=[]
    for fld in fields:
        result.append(float(record[fld]) if record[fld] is not None else 0.0)
    return result

fields=["defaultPrice", "price", "averageCost", "listPrice", "basePrice"]

product_1_id="GZ-2002"
product_1=get_product_price(product_1_id)
product_2_id="DemoProduct-2"
product_2=get_product_price(product_2_id)
df = pd.DataFrame({product_1_id: pickup(product_1, fields), 
                  product_2_id: pickup(product_2, fields)}, 
                  columns=[product_1_id, product_2_id])
df.head()
# Out:
#    GZ-2002  DemoProduct-2
# 0    47.99            5.0
# 1    47.99            5.0
# 2    48.00            0.0
# 3    48.00            0.0
# 4    47.99            5.0

# %%
plt.figure()
df.plot.hist(alpha=0.8)

# %%
df.diff().hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11531cd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11578fcf8>]],
#       dtype=object)

# %%
df['GZ-2002'].plot()

# %%
import datetime
from datetime import date
import time
from datetime import timedelta

print(datetime.date(2018, 12, 31))
print(time.time())
print(date.fromtimestamp(time.time()))
print(datetime.datetime.fromtimestamp(time.time()))
print(datetime.datetime.fromtimestamp(1548508174854/1000))

year = timedelta(days=365)
hundred_years = 100 * year
default_thru=date.today()+hundred_years
print(default_thru)
# Out:
# 2018-12-31
# 1549370650.007912
# 2019-02-05
# 2019-02-05 20:44:10.008156
# 2019-01-26 21:09:34.854000
# 2119-01-12

# %%
ent=MetaEntity("ProductPrice")
field_names=model.field_names

# %%
import pyarrow as pa

records=OfEntity().listProductPrice()
data=[]
skip_fields=['lastModifiedDate']
pnames=[]
for fld in field_names:
    if fld not in skip_fields:
        pnames.append(fld)
        
        field_arr=[]
        model_fld=ent.model.getField(fld)
        fld_type=model_fld.getType()
        # print('- ', fld, fld_type)    
        for rec in records:
            val=rec[fld]
            if val is None:
                if fld=='thruDate':
                    val=default_thru                
            elif fld_type=='date-time':
                time_ms=rec[fld].getTime()
                val=datetime.datetime.fromtimestamp(time_ms/1000)
            
            field_arr.append(val)
        data.append(pa.array(field_arr))
        
batch = pa.RecordBatch.from_arrays(data, pnames)
batches = [batch] 
table = pa.Table.from_batches(batches)
print(table, table.num_rows, table.num_columns)
# Out:
# pyarrow.Table
# taxInPrice: null
# termUomId: null
# priceWithTax: null
# createdStamp: timestamp[us]
# productStoreGroupId: string
# taxAuthPartyId: null
# lastModifiedByUserLogin: string
# customPriceCalcService: null
# price: decimal(6, 3)
# taxAuthGeoId: null
# productPricePurposeId: string
# createdByUserLogin: string
# lastUpdatedStamp: timestamp[us]
# productId: string
# createdTxStamp: timestamp[us]
# taxPercentage: null
# lastUpdatedTxStamp: timestamp[us]
# thruDate: date32[day]
# fromDate: timestamp[us]
# currencyUomId: string
# createdDate: timestamp[us]
# priceWithoutTax: null
# taxAmount: null
# productPriceTypeId: string 10 24

# %%
df= table.to_pandas()
df.head()
# Out:
#   taxInPrice termUomId priceWithTax            createdStamp  \
# 0       None      None         None 2019-01-26 21:09:34.854
# 1       None      None         None 2019-01-26 21:09:34.852
# 2       None      None         None 2019-01-26 21:09:34.853
# 3       None      None         None 2019-01-26 21:09:34.855
# 4       None      None         None 2019-01-26 21:09:27.253
#
#   productStoreGroupId taxAuthPartyId lastModifiedByUserLogin  \
# 0                _NA_           None                   admin
# 1                _NA_           None                   admin
# 2                _NA_           None                   admin
# 3                _NA_           None                   admin
# 4                _NA_           None                    None
#
#   customPriceCalcService    price taxAuthGeoId        ...          \
# 0                   None  922.000         None        ...
# 1                   None  549.990         None        ...
# 2                   None  550.000         None        ...
# 3                   None    5.990         None        ...
# 4                   None    9.990         None        ...
#
#            createdTxStamp taxPercentage      lastUpdatedTxStamp    thruDate  \
# 0 2019-01-26 21:09:34.661          None 2019-01-26 21:09:34.661  2119-01-12
# 1 2019-01-26 21:09:34.661          None 2019-01-26 21:09:34.661  2119-01-12
# 2 2019-01-26 21:09:34.661          None 2019-01-26 21:09:34.661  2119-01-12
# 3 2019-01-26 21:09:34.661          None 2019-01-26 21:09:34.661  2119-01-12
# 4 2019-01-26 21:09:22.215          None 2019-01-26 21:09:22.215  2119-01-12
#
#                  fromDate currencyUomId         createdDate priceWithoutTax  \
# 0 2001-05-13 12:00:00.000           EUR 2001-05-13 12:00:00            None
# 1 2001-05-13 12:00:00.000           EUR 2001-05-13 12:00:00            None
# 2 2001-05-13 12:00:00.000           EUR 2001-05-13 12:00:00            None
# 3 2003-03-04 18:50:45.250           EUR 2001-05-13 12:00:00            None
# 4 2011-08-02 12:00:00.000           USD 2011-08-02 12:00:00            None
#
#   taxAmount productPriceTypeId
# 0      None  COMPETITIVE_PRICE
# 1      None      DEFAULT_PRICE
# 2      None         LIST_PRICE
# 3      None      DEFAULT_PRICE
# 4      None      DEFAULT_PRICE
#
# [5 rows x 24 columns]

# %%
import pandas as pd
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
from sagas.ofbiz.entities import oc,finder,OfEntity, MetaEntity
from sagas.ofbiz.services import OfService
ent=MetaEntity("ProductPrice")
model_desc={'name':[str(fld.getName()) for fld in ent.model.getFieldsIterator()], 
            'type':[str(fld.getType()) for fld in ent.model.getFieldsIterator()], 
            'primary': ['*' if fld.getIsPk() else ' '  for fld in ent.model.getFieldsIterator()]
           }
df = pd.DataFrame(model_desc)
df
# Out:
#                        name primary              type
# 0                 productId       *                id
# 1        productPriceTypeId       *                id
# 2     productPricePurposeId       *                id
# 3             currencyUomId       *                id
# 4       productStoreGroupId       *                id
# 5                  fromDate       *         date-time
# 6                  thruDate                 date-time
# 7                     price          currency-precise
# 8                 termUomId                        id
# 9    customPriceCalcService                        id
# 10          priceWithoutTax          currency-precise
# 11             priceWithTax          currency-precise
# 12                taxAmount          currency-precise
# 13            taxPercentage               fixed-point
# 14           taxAuthPartyId                        id
# 15             taxAuthGeoId                        id
# 16               taxInPrice                 indicator
# 17              createdDate                 date-time
# 18       createdByUserLogin                  id-vlong
# 19         lastModifiedDate                 date-time
# 20  lastModifiedByUserLogin                  id-vlong
# 21         lastUpdatedStamp                 date-time
# 22       lastUpdatedTxStamp                 date-time
# 23             createdStamp                 date-time
# 24           createdTxStamp                 date-time

# %%
from sagas.ofbiz.entities import oc,finder,OfEntity, MetaEntity
from sagas.ofbiz.services import OfService

def create_data_frame(ent_name):
    ent=MetaEntity(ent_name)
    model_desc={'name':[str(fld.getName()) for fld in ent.model.getFieldsIterator()], 
                'type':[str(fld.getType()) for fld in ent.model.getFieldsIterator()], 
                'primary': ['*' if fld.getIsPk() else ' '  for fld in ent.model.getFieldsIterator()]
               }
    df = pd.DataFrame(model_desc)
    df['field type']=df['type'].astype('category')
    # df.sort_values(by='field type')
    return df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
# name       25 non-null object
# primary    25 non-null object
# type       25 non-null object
# dtypes: object(3)
# memory usage: 680.0+ bytes

# %%
df['field type']=df['type'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
# name          25 non-null object
# primary       25 non-null object
# type          25 non-null object
# field type    25 non-null category
# dtypes: category(1), object(3)
# memory usage: 913.0+ bytes

# %%
df
# Out:
#                        name primary              type        field type
# 0                 productId       *                id                id
# 1        productPriceTypeId       *                id                id
# 2     productPricePurposeId       *                id                id
# 3             currencyUomId       *                id                id
# 4       productStoreGroupId       *                id                id
# 5                  fromDate       *         date-time         date-time
# 6                  thruDate                 date-time         date-time
# 7                     price          currency-precise  currency-precise
# 8                 termUomId                        id                id
# 9    customPriceCalcService                        id                id
# 10          priceWithoutTax          currency-precise  currency-precise
# 11             priceWithTax          currency-precise  currency-precise
# 12                taxAmount          currency-precise  currency-precise
# 13            taxPercentage               fixed-point       fixed-point
# 14           taxAuthPartyId                        id                id
# 15             taxAuthGeoId                        id                id
# 16               taxInPrice                 indicator         indicator
# 17              createdDate                 date-time         date-time
# 18       createdByUserLogin                  id-vlong          id-vlong
# 19         lastModifiedDate                 date-time         date-time
# 20  lastModifiedByUserLogin                  id-vlong          id-vlong
# 21         lastUpdatedStamp                 date-time         date-time
# 22       lastUpdatedTxStamp                 date-time         date-time
# 23             createdStamp                 date-time         date-time
# 24           createdTxStamp                 date-time         date-time

# %%
df.sort_values(by='field type')
# Out:
#                        name primary              type        field type
# 12                taxAmount          currency-precise  currency-precise
# 11             priceWithTax          currency-precise  currency-precise
# 7                     price          currency-precise  currency-precise
# 10          priceWithoutTax          currency-precise  currency-precise
# 22       lastUpdatedTxStamp                 date-time         date-time
# 21         lastUpdatedStamp                 date-time         date-time
# 19         lastModifiedDate                 date-time         date-time
# 17              createdDate                 date-time         date-time
# 23             createdStamp                 date-time         date-time
# 24           createdTxStamp                 date-time         date-time
# 6                  thruDate                 date-time         date-time
# 5                  fromDate       *         date-time         date-time
# 13            taxPercentage               fixed-point       fixed-point
# 8                 termUomId                        id                id
# 14           taxAuthPartyId                        id                id
# 15             taxAuthGeoId                        id                id
# 4       productStoreGroupId       *                id                id
# 3             currencyUomId       *                id                id
# 2     productPricePurposeId       *                id                id
# 1        productPriceTypeId       *                id                id
# 9    customPriceCalcService                        id                id
# 0                 productId       *                id                id
# 18       createdByUserLogin                  id-vlong          id-vlong
# 20  lastModifiedByUserLogin                  id-vlong          id-vlong
# 16               taxInPrice                 indicator         indicator

# %%
df.groupby("field type").size()
# Out:
# field type
# currency-precise    4
# date-time           8
# fixed-point         1
# id                  9
# id-vlong            2
# indicator           1
# dtype: int64

# %%
from sagas.ofbiz.entities import search_entity
search_entity('product')
# Out:
# SupplierProductFeature
# ProductStoreKeywordOvrd
# ProductPricePurpose
# ProductConfigOption
# ProductCategoryRole
# ProductConfigOptionIactn
# ProductFacilityLocation
# ProductStoreCatalog
# SupplierProductAndProduct
# OrderReportPurchasesGroupByProduct
# OrderItemAndProductContentInfo
# ProductStore
# ProductPrice
# ProductFeatureGroupAndAppl
# ProductPriceAction
# ProductPromo
# ProductContentAndInfo
# ConfigOptionProductOption
# ProductFeaturePrice
# ProductStoreRole
# ProductStoreEmailSetting
# ProductStoreGroupRollup
# ProductCategoryContentType
# OrderItemAndProduct
# ProductAndAssoc
# ProductPromoCategory
# ProductCategoryAndMember
# ContentApprovalProductContentAndInfo
# ProductFeatureAndAppl
# ProductAverageCost
# ProductStoreFacility
# ProductFeatureCategoryAppl
# ProductFeatureIactnType
# ProductKeyword
# ProductPromoCodeParty
# ProductStorePromoAppl
# OrderHeaderAndShipGroupsByProduct
# ProductGlAccount
# ProductCategoryLink
# ProductFacilityAndPostalAddress
# ProductPromoAction
# ProductPriceChange
# ProductType
# ProductFeatureCatGrpAppl
# ProductReview
# ProductManufacturingRule
# ProductPriceType
# ProductCategoryAttribute
# RequirementPartyProductCount
# ProductPaymentMethodType
# ProductCategoryMemberAndPrice
# VendorProduct
# ProductStoreSurveyAppl
# ProductMeter
# ProductPromoCode
# ProductConfigProduct
# ProductFacilityLocationView
# ProductMeterType
# ProductAndCategoryMember
# ProductAttribute
# ProductGeo
# ProductCategoryMemberAndRole
# ProductFeatureDataResource
# ProductCalculatedInfo
# InvoiceItemProductSummary
# ProductAssocType
# ProductRole
# ProductMaint
# TaxAuthorityRateProduct
# ProductStoreGroupMember
# ProductStorePromoAndAppl
# ProductFeatureAppl
# ProductPriceActionType
# ProductFacility
# WorkEffortProductGoods
# ProductStorePaymentSetting
# CommunicationEventAndProduct
# RequirementByProductFacility
# ProductAndPriceView
# Product
# ProductAssoc
# ProductStoreFinActSetting
# ProductStoreGroup
# ProductStoreGroupRole
# ProductFeatureApplAttr
# ProductGroupOrder
# ProductCategoryRollupAndRole
# ProductVirtualAndAssocPrices
# ProductCategoryContentAndInfo
# ProductMaintType
# ProductPriceAutoNotice
# ProductStoreShipmentMethView
# ProductConfigAndProduct
# ProductSearchConstraint
# ProductInventoryItem
# ProductPromoUseCheck
# OrderProductPromoCode
# ProductCategoryMember
# ProductCategoryRollup
# ProductCostComponentCalc
# CommunicationEventProduct
# SupplierProduct
# ProductFeatureGroup
# ProductPromoCond
# OrderReportSalesGroupByProduct
# ProductPriceRule
# ProductContent
# ProductPriceCond
# ProductPromoRule
# OrderRoleAndProductContentInfo
# ProductPromoCodeEmail
# ProductStoreGroupRollupAndChild
# ProductPromoContent
# ProductFeatureIactn
# ProductPromoUse
# FixedAssetProduct
# ProductCategoryGlAccount
# ProductStoreVendorPayment
# ProductStoreVendorShipment
# ProductPromoCodeEmailParty
# OrderReportGroupByProduct
# ProductAverageCostType
# ProductFeatureCategory
# ProductFeatureGroupAppl
# InvoiceItemAndAssocProduct
# ProductFeatureType
# ProductConfigStats
# ProductCategoryType
# ProductStoreShipmentMeth
# ProductCategory
# ProductTypeAttr
# FixedAssetProductType
# ProductConfig
# ProductFeature
# ProductOrderItem
# ProductCategoryTypeAttr
# ProductSearchResult
# ProductCategoryRollupAndChild
# ProductSubscriptionResource
# ProductVirtualAndVariantInfo
# ProductStoreFacilityByOrder
# GoodIdentificationAndProduct
# OrderItemQuantityReportGroupByProduct
# ProductPromoProduct
# ProductFacilityLocationQuantityTest
# ProductStoreGroupType
# ProductCategoryContent
# ProductFeatureApplType
# OrderPurchaseProductSummary
# ProductConfigItem
# ProductConfigConfig
# ProductStoreGroupAndMember
# AgreementItemAndProductAppl
# ProductContentType
# AgreementProductAppl

# %%
df_ent=create_data_frame('ProductAndCategoryMember')
df_ent
# Out:
#                           name primary             type       field type
# 0               memberComments                  comment          comment
# 1                  originGeoId                       id               id
# 2                 detailScreen             long-varchar     long-varchar
# 3             requireInventory                indicator        indicator
# 4                quantityUomId                       id               id
# 5               mediumImageUrl                      url              url
# 6                  productName                     name             name
# 7             introductionDate                date-time        date-time
# 8               shippingHeight              fixed-point      fixed-point
# 9             originalImageUrl                      url              url
# 10               inShippingBox                indicator        indicator
# 11              detailImageUrl                      url              url
# 12  supportDiscontinuationDate                date-time        date-time
# 13                productWidth              fixed-point      fixed-point
# 14         includeInPromotions                indicator        indicator
# 15                    configId                       id               id
# 16         billOfMaterialLevel                  numeric          numeric
# 17               lotIdFilledIn             long-varchar     long-varchar
# 18               productRating              fixed-point      fixed-point
# 19          createdByUserLogin                 id-vlong         id-vlong
# 20                   brandName                     name             name
# 21               requireAmount                indicator        indicator
# 22                   productId       *               id               id
# 23               smallImageUrl                      url              url
# 24                     taxable                indicator        indicator
# 25    primaryProductCategoryId                       id               id
# 26    salesDiscontinuationDate                date-time        date-time
# 27       salesDiscWhenNotAvail                indicator        indicator
# 28                  returnable                indicator        indicator
# 29                 weightUomId                       id               id
# ..                         ...     ...              ...              ...
# 46     lastModifiedByUserLogin                 id-vlong         id-vlong
# 47    virtualVariantMethodEnum                       id               id
# 48              shippingWeight              fixed-point      fixed-point
# 49               shippingWidth              fixed-point      fixed-point
# 50               shippingDepth              fixed-point      fixed-point
# 51            reservMaxPersons              fixed-point      fixed-point
# 52                 fixedAmount          currency-amount  currency-amount
# 53         inventoryItemTypeId                       id               id
# 54              piecesIncluded                  numeric          numeric
# 55                productDepth              fixed-point      fixed-point
# 56                  facilityId                       id               id
# 57                    comments                  comment          comment
# 58                 releaseDate                date-time        date-time
# 59               productHeight              fixed-point      fixed-point
# 60            lastModifiedDate                date-time        date-time
# 61    defaultShipmentBoxTypeId                       id               id
# 62        orderDecimalQuantity                indicator        indicator
# 63            inventoryMessage              description      description
# 64               productWeight              fixed-point      fixed-point
# 65                  depthUomId                       id               id
# 66               productTypeId                       id               id
# 67                 createdDate                date-time        date-time
# 68                   isVariant                indicator        indicator
# 69               largeImageUrl                      url              url
# 70     requirementMethodEnumId                       id               id
# 71                    fromDate       *        date-time        date-time
# 72           productCategoryId       *               id               id
# 73                    quantity              fixed-point      fixed-point
# 74                 sequenceNum                  numeric          numeric
# 75                    thruDate                date-time        date-time
#
# [76 rows x 4 columns]

# %%
df.sort_values(by='name')
# Out:
#                        name primary              type        field type
# 18       createdByUserLogin                  id-vlong          id-vlong
# 17              createdDate                 date-time         date-time
# 23             createdStamp                 date-time         date-time
# 24           createdTxStamp                 date-time         date-time
# 3             currencyUomId       *                id                id
# 9    customPriceCalcService                        id                id
# 5                  fromDate       *         date-time         date-time
# 20  lastModifiedByUserLogin                  id-vlong          id-vlong
# 19         lastModifiedDate                 date-time         date-time
# 21         lastUpdatedStamp                 date-time         date-time
# 22       lastUpdatedTxStamp                 date-time         date-time
# 7                     price          currency-precise  currency-precise
# 11             priceWithTax          currency-precise  currency-precise
# 10          priceWithoutTax          currency-precise  currency-precise
# 0                 productId       *                id                id
# 2     productPricePurposeId       *                id                id
# 1        productPriceTypeId       *                id                id
# 4       productStoreGroupId       *                id                id
# 12                taxAmount          currency-precise  currency-precise
# 15             taxAuthGeoId                        id                id
# 14           taxAuthPartyId                        id                id
# 16               taxInPrice                 indicator         indicator
# 13            taxPercentage               fixed-point       fixed-point
# 8                 termUomId                        id                id
# 6                  thruDate                 date-time         date-time

# %%
from sagas.ofbiz.services import OfService, MetaService
from py4j.java_gateway import get_field

def create_service_data_frame(name):
    model=MetaService(name).model
    params=model.getModelParamList()
    model_desc={'name':[str(get_field(param, "name")) for param in params],
                'type':[str(get_field(param, "type")) for param in params],
                'primary': ['*' if not get_field(param, "optional") else ' '  for param in params],
                'entity name': [str(get_field(param, "entityName")) for param in params],
                'mode':[str(get_field(param, "mode")) for param in params],
                'description':[str(get_field(param, "description")) for param in params]
               }
    df = pd.DataFrame(model_desc)
    df['parameter mode']=df['mode'].astype('category')
    # return df.sort_values(by='parameter mode')
    return df

create_service_data_frame('calculateProductPrice')
# Out:
#    description entity name   mode                     name primary  \
# 0                              IN                  product       *
# 1                              IN            prodCatalogId
# 2                              IN                webSiteId
# 3                              IN                  partyId
# 4                              IN           productStoreId
# 5                              IN      productStoreGroupId
# 6                              IN              agreementId
# 7                              IN                 quantity
# 8                              IN                   amount
# 9                              IN            currencyUomId
# 10                             IN          currencyUomIdTo
# 11                             IN    productPricePurposeId
# 12                             IN                termUomId
# 13                             IN            autoUserLogin
# 14                             IN          checkIncludeVat
# 15                             IN    findAllQuantityPrices
# 16                             IN         surveyResponseId
# 17                             IN         customAttributes
# 18                            OUT                basePrice       *
# 19                            OUT                    price       *
# 20                            OUT                listPrice
# 21                            OUT             defaultPrice
# 22                            OUT         competitivePrice
# 23                            OUT              averageCost
# 24                            OUT               promoPrice
# 25                            OUT        specialPromoPrice
# 26                            OUT                   isSale       *
# 27                            OUT          validPriceFound       *
# 28                            OUT             currencyUsed       *
# 29                            OUT      orderItemPriceInfos       *
# 30                            OUT        allQuantityPrices
# 31                             IN  optimizeForLargeRuleSet
# 32        None        None    OUT          responseMessage
# 33        None        None    OUT             errorMessage
# 34        None        None    OUT         errorMessageList
# 35        None        None    OUT           successMessage
# 36        None        None    OUT       successMessageList
# 37        None        None  INOUT                userLogin
# 38        None        None     IN           login.username
# 39        None        None     IN           login.password
# 40        None        None  INOUT                   locale
# 41        None        None  INOUT                 timeZone
# 42        None        None  INOUT              visualTheme
#
#                                             type parameter mode
# 0           org.apache.ofbiz.entity.GenericValue             IN
# 1                                         String             IN
# 2                                         String             IN
# 3                                         String             IN
# 4                                         String             IN
# 5                                         String             IN
# 6                                         String             IN
# 7                                     BigDecimal             IN
# 8                                     BigDecimal             IN
# 9                                         String             IN
# 10                                        String             IN
# 11                                        String             IN
# 12                                        String             IN
# 13          org.apache.ofbiz.entity.GenericValue             IN
# 14                                        String             IN
# 15                                        String             IN
# 16                                        String             IN
# 17                                           Map             IN
# 18                                    BigDecimal            OUT
# 19                                    BigDecimal            OUT
# 20                                    BigDecimal            OUT
# 21                                    BigDecimal            OUT
# 22                                    BigDecimal            OUT
# 23                                    BigDecimal            OUT
# 24                                    BigDecimal            OUT
# 25                                    BigDecimal            OUT
# 26                                       Boolean            OUT
# 27                                       Boolean            OUT
# 28                                        String            OUT
# 29                                java.util.List            OUT
# 30                                java.util.List            OUT
# 31                                        String             IN
# 32                                        String            OUT
# 33                                        String            OUT
# 34                                java.util.List            OUT
# 35                                        String            OUT
# 36                                java.util.List            OUT
# 37          org.apache.ofbiz.entity.GenericValue          INOUT
# 38                                        String             IN
# 39                                        String             IN
# 40                              java.util.Locale          INOUT
# 41                            java.util.TimeZone          INOUT
# 42  org.apache.ofbiz.widget.renderer.VisualTheme          INOUT

# %%
def create_relation_data_frame(ent_name):
    ent=MetaEntity(ent_name)
    rels=ent.model.getRelationsList(True, True, True)
    model_desc={'entity name':[str(fld.getRelEntityName()) for fld in rels], 
                'type':[str(fld.getType()) for fld in rels], 
                'relation':[rel.getTitle()+rel.getRelEntityName() for rel in rels]
               }
    df = pd.DataFrame(model_desc)
    df['relation type']=df['type'].astype('category')
    # df.sort_values(by='field type')
    return df

create_relation_data_frame("Product")
# Out:
#                     entity name                              relation  type  \
# 0                   ProductType                           ProductType   one
# 1               ProductTypeAttr                       ProductTypeAttr  many
# 2               ProductCategory                PrimaryProductCategory   one
# 3                      Facility                              Facility   one
# 4                           Uom                           QuantityUom   one
# 5                       UomType                         AmountUomType   one
# 6                           Uom                             WeightUom   one
# 7                           Uom                             HeightUom   one
# 8                           Uom                              WidthUom   one
# 9                           Uom                              DepthUom   one
# 10                          Uom                           DiameterUom   one
# 11                  Enumeration       VirtualVariantMethodEnumeration   one
# 12                  Enumeration                     RatingEnumeration   one
# 13                  Enumeration          RequirementMethodEnumeration   one
# 14                          Geo                             OriginGeo   one
# 15                    UserLogin                    CreatedByUserLogin   one
# 16                    UserLogin               LastModifiedByUserLogin   one
# 17        ProductFeatureAndAppl                 ProductFeatureAndAppl  many
# 18              ShipmentBoxType                DefaultShipmentBoxType   one
# 19            InventoryItemType                     InventoryItemType   one
# 20                    Agreement                             Agreement  many
# 21         AgreementProductAppl                  AgreementProductAppl  many
# 22            CartAbandonedLine                     CartAbandonedLine  many
# 23    CommunicationEventProduct             CommunicationEventProduct  many
# 24                CostComponent                         CostComponent  many
# 25              CustRequestItem                       CustRequestItem  many
# 26                   FixedAsset                  InstanceOfFixedAsset  many
# 27            FixedAssetProduct                     FixedAssetProduct  many
# 28           GoodIdentification                    GoodIdentification  many
# 29                InventoryItem                         InventoryItem  many
# ..                          ...                                   ...   ...
# 52             ProductGlAccount                      ProductGlAccount  many
# 53            ProductGroupOrder                     ProductGroupOrder  many
# 54               ProductKeyword                        ProductKeyword  many
# 55                 ProductMaint                          ProductMaint  many
# 56     ProductManufacturingRule              ProductManufacturingRule  many
# 57     ProductManufacturingRule    ProductForProductManufacturingRule  many
# 58     ProductManufacturingRule     ProductInProductManufacturingRule  many
# 59     ProductManufacturingRule  ProductSubstProductManufacturingRule  many
# 60                 ProductMeter                          ProductMeter  many
# 61             ProductOrderItem                      ProductOrderItem  many
# 62     ProductPaymentMethodType              ProductPaymentMethodType  many
# 63                 ProductPrice                          ProductPrice  many
# 64          ProductPromoProduct                   ProductPromoProduct  many
# 65                ProductReview                         ProductReview  many
# 66                  ProductRole                           ProductRole  many
# 67       ProductStoreSurveyAppl                ProductStoreSurveyAppl  many
# 68  ProductSubscriptionResource           ProductSubscriptionResource  many
# 69                    QuoteItem                             QuoteItem  many
# 70             ReorderGuideline                      ReorderGuideline  many
# 71                  Requirement                           Requirement  many
# 72                   ReturnItem                            ReturnItem  many
# 73          SalesForecastDetail                   SalesForecastDetail  many
# 74                 ShipmentItem                          ShipmentItem  many
# 75       ShipmentPackageContent             SubShipmentPackageContent  many
# 76              ShipmentReceipt                       ShipmentReceipt  many
# 77             ShoppingListItem                      ShoppingListItem  many
# 78                 Subscription                          Subscription  many
# 79              SupplierProduct                       SupplierProduct  many
# 80                VendorProduct                         VendorProduct  many
# 81       WorkEffortGoodStandard                WorkEffortGoodStandard  many
#
#    relation type
# 0            one
# 1           many
# 2            one
# 3            one
# 4            one
# 5            one
# 6            one
# 7            one
# 8            one
# 9            one
# 10           one
# 11           one
# 12           one
# 13           one
# 14           one
# 15           one
# 16           one
# 17          many
# 18           one
# 19           one
# 20          many
# 21          many
# 22          many
# 23          many
# 24          many
# 25          many
# 26          many
# 27          many
# 28          many
# 29          many
# ..           ...
# 52          many
# 53          many
# 54          many
# 55          many
# 56          many
# 57          many
# 58          many
# 59          many
# 60          many
# 61          many
# 62          many
# 63          many
# 64          many
# 65          many
# 66          many
# 67          many
# 68          many
# 69          many
# 70          many
# 71          many
# 72          many
# 73          many
# 74          many
# 75          many
# 76          many
# 77          many
# 78          many
# 79          many
# 80          many
# 81          many
#
# [82 rows x 4 columns]
