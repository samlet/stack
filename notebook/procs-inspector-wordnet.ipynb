# %%
import json
x={'x':True, 'y':'s'}
print(json.dumps(x))
y=False
print(json.dumps(y))
# Out:
# {"x": true, "y": "s"}
# false

# %%
subs=[4,5]
rs=[1,2,3, *subs]
rs
# Out:
# [1, 2, 3, 4, 5]

# %%
from sagas.nlu.wordnet_procs import *
def check_chains(synsets:list, kind):    
    kind_set=set(kind.split('/'))
    for index, c in enumerate(synsets):
        # c = wn.synset(synset)
        chain = {}
        for c_c in [c]+list(c.closure(hyper)):
            key=c_c.name().split('.')[0]
            if key in chain:
                print('!! duplicated key %s'%c_c.name())
            chain[key]=c_c.name()
        container=set(chain.keys())
        check_r=kind_set.issubset(container)
        # print(index, check_r, container)        
        if check_r:
            return True, {'index':0, 'keys':container, 'chain':chain}
    return False, None
        
def predicate_chain(word, kind, lang='en', pos='n'):
    from sagas.nlu.locales import iso_locales
    loc, _ = iso_locales.get_code_by_part1(lang)
    sets = wn.synsets(word, lang=loc, pos=None if pos=='*' else pos)
    ret=False
    if len(sets)>=0:            
        # c=[s.name() for s in sets]
        return check_chains(sets, kind)
    return ret, None
predicate_chain('dog', 'animal/dog')
# Out:
# (True,
#  {'chain': {'animal': 'animal.n.01',
#    'canine': 'canine.n.02',
#    'carnivore': 'carnivore.n.01',
#    'chordate': 'chordate.n.01',
#    'dog': 'dog.n.01',
#    'domestic_animal': 'domestic_animal.n.01',
#    'entity': 'entity.n.01',
#    'living_thing': 'living_thing.n.01',
#    'mammal': 'mammal.n.01',
#    'object': 'object.n.01',
#    'organism': 'organism.n.01',
#    'physical_entity': 'physical_entity.n.01',
#    'placental': 'placental.n.01',
#    'vertebrate': 'vertebrate.n.01',
#    'whole': 'whole.n.02'},
#   'index': 0,
#   'keys': {'animal',
#    'canine',
#    'carnivore',
#    'chordate',
#    'dog',
#    'domestic_animal',
#    'entity',
#    'living_thing',
#    'mammal',
#    'object',
#    'organism',
#    'physical_entity',
#    'placental',
#    'vertebrate',
#    'whole'}})

# %%
import requests
from pprint import pprint
word='menina'
lang='pt'
pos='n'

response = requests.post('http://localhost:8093/word_sets',
                                 json={'word':word, 'lang':lang, 'pos':pos})
# print(response.status_code, response.json())
if response.status_code == 200:
    rs=response.json()
    print('synsets:', ', '.join([r['name'].split('.')[0] for r in rs]))
    pprint(rs)
else:
    print('fail')
# Out:
# synsets: child, dame, female_child, girlfriend, lass, prostitute
# [{'definition': 'an immature childish person',
#   'domains': {'region': [], 'topic': [], 'usage': []},
#   'examples': ['he remained a child in practical matters as long as he lived',
#                'stop being a baby!'],
#   'name': 'child.n.03'},
#  {'definition': 'informal terms for a (young) woman',
#   'domains': {'region': [], 'topic': [], 'usage': []},
#   'examples': [],
#   'name': 'dame.n.01'},
#  {'definition': 'a youthful female person',
#   'domains': {'region': [], 'topic': [], 'usage': []},
#   'examples': ['the baby was a girl',
#                'the girls were just learning to ride a tricycle'],
#   'name': 'female_child.n.01'},
#  {'definition': 'a girl or young woman with whom a man is romantically '
#                 'involved',
#   'domains': {'region': [], 'topic': [], 'usage': []},
#   'examples': ['his girlfriend kicked him out'],
#   'name': 'girlfriend.n.02'},
#  {'definition': 'a girl or young woman who is unmarried',
#   'domains': {'region': [], 'topic': [], 'usage': []},
#   'examples': [],
#   'name': 'lass.n.01'},
#  {'definition': 'a woman who engages in sexual intercourse for money',
#   'domains': {'region': [], 'topic': [], 'usage': []},
#   'examples': [],
#   'name': 'prostitute.n.01'}]

# %%
response = requests.post('http://localhost:8093/get_chains',
                                 json={'word':word, 'lang':lang, 'pos':pos})
# print(response.status_code, response.json())
if response.status_code == 200:
    rs=response.json()
    pprint(rs)
else:
    print('fail')
# Out:
# [{'chain': ['child.n.03',
#             'person.n.01',
#             'causal_agent.n.01',
#             'organism.n.01',
#             'physical_entity.n.01',
#             'living_thing.n.01',
#             'entity.n.01',
#             'whole.n.02',
#             'object.n.01'],
#   'name': 'child.n.03',
#   'offset': 9918554},
#  {'chain': ['dame.n.01',
#             'girl.n.01',
#             'woman.n.01',
#             'adult.n.01',
#             'female.n.02',
#             'person.n.01',
#             'causal_agent.n.01',
#             'organism.n.01',
#             'physical_entity.n.01',
#             'living_thing.n.01',
#             'entity.n.01',
#             'whole.n.02',
#             'object.n.01'],
#   'name': 'dame.n.01',
#   'offset': 9989045},
#  {'chain': ['female_child.n.01',
#             'female.n.02',
#             'person.n.01',
#             'causal_agent.n.01',
#             'organism.n.01',
#             'physical_entity.n.01',
#             'living_thing.n.01',
#             'entity.n.01',
#             'whole.n.02',
#             'object.n.01'],
#   'name': 'female_child.n.01',
#   'offset': 10084295},
#  {'chain': ['girlfriend.n.02',
#             'lover.n.01',
#             'woman.n.01',
#             'person.n.01',
#             'adult.n.01',
#             'female.n.02',
#             'causal_agent.n.01',
#             'organism.n.01',
#             'physical_entity.n.01',
#             'living_thing.n.01',
#             'entity.n.01',
#             'whole.n.02',
#             'object.n.01'],
#   'name': 'girlfriend.n.02',
#   'offset': 10130686},
#  {'chain': ['lass.n.01',
#             'girl.n.01',
#             'woman.n.01',
#             'adult.n.01',
#             'female.n.02',
#             'person.n.01',
#             'causal_agent.n.01',
#             'organism.n.01',
#             'physical_entity.n.01',
#             'living_thing.n.01',
#             'entity.n.01',
#             'whole.n.02',
#             'object.n.01'],
#   'name': 'lass.n.01',
#   'offset': 10247358},
#  {'chain': ['prostitute.n.01',
#             'woman.n.01',
#             'adult.n.01',
#             'female.n.02',
#             'person.n.01',
#             'causal_agent.n.01',
#             'organism.n.01',
#             'physical_entity.n.01',
#             'living_thing.n.01',
#             'entity.n.01',
#             'whole.n.02',
#             'object.n.01'],
#   'name': 'prostitute.n.01',
#   'offset': 10485440}]

# %%
from sagas.nlu.wordnet_procs import check_chains, hyper
from sagas.nlu.locales import iso_locales
from nltk.corpus import wordnet as wn

word='menina'
lang='pt'
pos='n'

loc, _ = iso_locales.get_code_by_part1(lang)
synsets = wn.synsets(word, lang=loc, pos=None if pos=='*' else pos)
    
chains=[]
for index, c in enumerate(synsets):
    print(c.offset(), c.name())
    chain_keys=[]
    for c_c in [c] + list(c.closure(hyper)):
        key = c_c.name()
        chain_keys.append(key)
    chains.append(chain_keys)

pprint(chains)
# Out:
# 9918554 child.n.03
# 9989045 dame.n.01
# 10084295 female_child.n.01
# 10130686 girlfriend.n.02
# 10247358 lass.n.01
# 10485440 prostitute.n.01
# [['child.n.03',
#   'person.n.01',
#   'causal_agent.n.01',
#   'organism.n.01',
#   'physical_entity.n.01',
#   'living_thing.n.01',
#   'entity.n.01',
#   'whole.n.02',
#   'object.n.01'],
#  ['dame.n.01',
#   'girl.n.01',
#   'woman.n.01',
#   'adult.n.01',
#   'female.n.02',
#   'person.n.01',
#   'causal_agent.n.01',
#   'organism.n.01',
#   'physical_entity.n.01',
#   'living_thing.n.01',
#   'entity.n.01',
#   'whole.n.02',
#   'object.n.01'],
#  ['female_child.n.01',
#   'female.n.02',
#   'person.n.01',
#   'causal_agent.n.01',
#   'organism.n.01',
#   'physical_entity.n.01',
#   'living_thing.n.01',
#   'entity.n.01',
#   'whole.n.02',
#   'object.n.01'],
#  ['girlfriend.n.02',
#   'lover.n.01',
#   'woman.n.01',
#   'person.n.01',
#   'adult.n.01',
#   'female.n.02',
#   'causal_agent.n.01',
#   'organism.n.01',
#   'physical_entity.n.01',
#   'living_thing.n.01',
#   'entity.n.01',
#   'whole.n.02',
#   'object.n.01'],
#  ['lass.n.01',
#   'girl.n.01',
#   'woman.n.01',
#   'adult.n.01',
#   'female.n.02',
#   'person.n.01',
#   'causal_agent.n.01',
#   'organism.n.01',
#   'physical_entity.n.01',
#   'living_thing.n.01',
#   'entity.n.01',
#   'whole.n.02',
#   'object.n.01'],
#  ['prostitute.n.01',
#   'woman.n.01',
#   'adult.n.01',
#   'female.n.02',
#   'person.n.01',
#   'causal_agent.n.01',
#   'organism.n.01',
#   'physical_entity.n.01',
#   'living_thing.n.01',
#   'entity.n.01',
#   'whole.n.02',
#   'object.n.01']]

# %%
import pandas as pd
df=pd.read_csv('/pi/ai/nltk/data/wikt/wn-wikt-rus.tab',sep='\t')
df=df
df.head()
# Out:
#   # Wiktionary        rus http://wiktionary.org/  CC BY-SA
# 0   00004171-a  rus:lemma              умирающий       NaN
# 1   00004171-a  rus:lemma            агонирующий       NaN
# 2   00004171-a  rus:lemma            загнивающий       NaN
# 3   00005205-a  rus:lemma             абсолютный       NaN
# 4   00005205-a  rus:lemma            совершенный       NaN

# %%
import json
tab=df.to_json(orient='split')
json_tab=json.loads(tab)
data=json_tab['data']
print('total:', len(data))
for row in data[:5]:
    print(row[0], row[2])
# Out:
# total: 33716
# 00004171-a умирающий
# 00004171-a агонирующий
# 00004171-a загнивающий
# 00005205-a абсолютный
# 00005205-a совершенный

# %%
import sagas
pos='n'
offset=str(9918554)
id='%s-%s'%(offset.zfill(8),pos)
rs=[]
for row in data:
    if row[0]==id:
        rs.append((row[0], row[2]))
sagas.to_df(rs, ['id', 'word'])
# Out:
#            id     word
# 0  09918554-n  ребёнок
# 1  09918554-n     дитя

# %%
import json
def get_word(offset):
    id='%s-%s'%(str(offset).zfill(8),pos)
    rs=[]
    for row in data:
        if row[0]==id:
            rs.append((row[0], row[2]))
    return rs

r=get_word(9918554)
json.dumps(r, ensure_ascii=False)
# Out:
# '[["09918554-n", "ребёнок"], ["09918554-n", "дитя"]]'

# %%
def get_def(part3):
    from iso639 import languages
    try:
        loc = languages.get(part3=part3)
    except KeyError:
        loc = None
    return loc
get_def('por').part1
# Out:
# 'pt'

# %%
Yoruba	yor	365	28	382	0%
Yue Chinese	yue	324	515	527	2%
Malaysian	zsm	37,423	35,035	106,640	97%
Zulu	zul	792	770	961	4%'''.split('\n')

# from sagas.nlu.locales import iso_locales
    
rs=[]
lang_maps={}
for line in omw_summx[1:]:
    row=line.split('\t')
    # row[5]=row[5].replace('%', 'p')
    progress=int(row[5].replace('%',''))
    if progress>50:
        lang=row[1]
        # loc, _ = iso_locales.get_code_by_part3(lang)
        loc=get_def(lang)
        if loc is None or loc.part1=='':
            row.append('_')
        else:
            row.append(loc.part1)
            lang_maps[loc.part1]=lang
        rs.append(row)
sagas.to_df(rs, omw_summx[0].split('\t')+['loc'])
# Out:
#                     Lang Code  Synsets    Words   Senses  Core loc
# 0                 Arabic  arb   14,650   24,713   46,417   62%   _
# 1              Bulgarian  bul   11,857   13,252   18,608   99%  bg
# 2                Catalan  cat   48,005   48,881   74,806   84%  ca
# 3                  Czech  ces   13,030   13,742   15,813   54%  cs
# 4   Chinese (simplified)  cmn   49,023   78,194  108,653  100%   _
# 5                 Danish  dan   10,328   10,560   13,550   85%  da
# 6                 German  deu   19,857   24,751   29,884   64%  de
# 7                  Greek  ell   24,264   24,921   34,121   70%  el
# 8                English  eng  117,659  151,688  213,480  100%  en
# 9                 Basque  eus   29,965   26,990   50,075   72%  eu
# 10                 Farsi  fas   20,766   20,574   35,318   55%  fa
# 11               Finnish  fin  116,830  133,987  199,515  100%  fi
# 12                French  fra   59,091   55,378  102,678   92%  fr
# 13              Croatian  hrv   23,406   29,308   48,285  100%  hr
# 14            Indonesian  ind   38,569   37,775  108,054   95%  id
# 15             Icelandic  isl    9,484   16,879   22,807   99%  is
# 16               Italian  ita   42,063   50,581   82,741   89%  it
# 17              Japanese  jpn   59,112   99,080  177,594   96%  ja
# 18                 Dutch  nld   33,925   46,552   69,088   79%  nl
# 19               Nynorsk  nno    5,162    5,035    6,664   66%  nn
# 20                Bokmål  nob   10,302   10,532   13,598   84%  nb
# 21                Polish  pol   37,696   49,395   59,870   68%  pl
# 22            Portuguese  por   43,895   54,071   74,012   84%  pt
# 23              Romanian  ron   57,254   52,772   90,336   95%  ro
# 24               Russian  rus   20,138   25,481   34,009   64%  ru
# 25                Slovak  slk   20,508   31,224   46,898   63%  sk
# 26               Slovene  slv   43,190   41,205   72,516   87%  sl
# 27               Spanish  spa   47,737   47,762   74,848   86%  es
# 28               Swedish  swe   15,751   15,934   20,754   99%  sv
# 29                  Thai  tha   73,593   83,658   97,388   81%  th
# 30             Malaysian  zsm   37,423   35,035  106,640   97%   _

# %%
print(lang_maps)
# Out:
# {'bg': 'bul', 'ca': 'cat', 'cs': 'ces', 'da': 'dan', 'de': 'deu', 'el': 'ell', 'en': 'eng', 'eu': 'eus', 'fa': 'fas', 'fi': 'fin', 'fr': 'fra', 'hr': 'hrv', 'id': 'ind', 'is': 'isl', 'it': 'ita', 'ja': 'jpn', 'nl': 'nld', 'nn': 'nno', 'nb': 'nob', 'pl': 'pol', 'pt': 'por', 'ro': 'ron', 'ru': 'rus', 'sk': 'slk', 'sl': 'slv', 'es': 'spa', 'sv': 'swe', 'th': 'tha'}
