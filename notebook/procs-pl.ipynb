# %%
from sagas.nlu.corenlp_helper import LangDialect as dia
dia('pl').ana('śpiewasz piosenkę.')

# %%
dia('pl').ana('Moja firma chce tworzyć narzędzia.')
# Out:
# text: Moja 	lemma: mój	upos: DET	xpos: adj:sg:nom:f:pos
# text: firma 	lemma: firma	upos: NOUN	xpos: subst:sg:nom:f
# text: chce 	lemma: chcieć	upos: VERB	xpos: fin:sg:ter:imperf
# text: tworzyć 	lemma: tworzyć	upos: VERB	xpos: inf:imperf
# text: narzędzia 	lemma: narzędzie	upos: NOUN	xpos: subst:pl:acc:n
# text: . 	lemma: .	upos: PUNCT	xpos: interp
# ('Moja', '2', 'det')
# ('firma', '3', 'nsubj')
# ('chce', '0', 'root')
# ('tworzyć', '3', 'xcomp')
# ('narzędzia', '4', 'obj')
# ('.', '3', 'punct')
