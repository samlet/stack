# %%
import uuid
str(uuid.uuid4())
# Out:
# 'f83a70a8-d5ba-44db-a15e-ba17fbaa7805'

# %%
from sagas.util.name_util import to_global_id, from_global_id
import io_utils

prefix='/pi/artifacts'
user='system'
folder=to_global_id('blueprint', 'demoProducts')
full_dir='%s/%s/%s'%(prefix, user, folder)
print(full_dir)
io_utils.create_dir(full_dir)
# Out:
# /pi/artifacts/system/Ymx1ZXByaW50OmRlbW9Qcm9kdWN0cw==

# %%
asset_dir='./assets/productsDomain/seed'
build_dir='./assets/productsDomain/build'

# %%
import os
import platform

def creation_date(path_to_file):
    """
    Try to get the date that a file was created, falling back to when it was
    last modified if that isn't possible.
    See http://stackoverflow.com/a/39501288/1709587 for explanation.
    """
    if platform.system() == 'Windows':
        return os.path.getctime(path_to_file)
    else:
        stat = os.stat(path_to_file)
        try:
            return stat.st_birthtime
        except AttributeError:
            # We're probably on Linux. No easy way to get creation dates here,
            # so we'll settle for when its content was last modified.
            return stat.st_mtime

print(creation_date(asset_dir))
# Out:
# 1553238674.9673362

# %%
import os.path, time
file=asset_dir+'/IssuanceTestData.xml'
print("last modified: %s" % time.ctime(os.path.getmtime(file)))
print("created: %s" % time.ctime(os.path.getctime(file)))
# Out:
# last modified: Fri Mar 22 15:11:29 2019
# created: Fri Mar 22 15:11:29 2019

# %%
import os, time
(mode, ino, dev, nlink, uid, gid, size, atime, mtime, ctime) = os.stat(file)
print("last modified: %s" % time.ctime(mtime))
print(mtime)
# Out:
# last modified: Fri Mar 22 15:11:29 2019
# 1553238689

# %%
file='IssuanceTestData.xml'
pytime = os.path.getmtime(os.path.join(asset_dir, file))
# ...
txttime = os.path.getmtime(os.path.join(build_dir, file))
# ...
print(pytime, txttime)
if (txttime > pytime):
    print(True)
else:
    print(False)
# Out:
# 1553274405.6859667 1553274244.5245712
# False

# %%
from sagas.ofbiz.services import OfService as s
target=os.path.join(asset_dir, file)
full_path=os.path.abspath(target)
ok, result=s().entityImport(filename=full_path)
print(ok,result)
# Out:
# True {'messages': ['Got 26 entities to write to the datasource.']}

# %%
import os
import xml.etree.ElementTree as ET
from sagas.ofbiz.entity_prefabs import EntityPrefabs

print(full_path)
tree = ET.parse(full_path)
root = tree.getroot()

prefabs = EntityPrefabs()
rs, ids=prefabs.convert_to_record_set(root)
# map(token, TaStringEntries)
print(rs)
# token list
print(ids)
# Out:
# /Users/xiaofeiwu/jcloud/assets/langs/workspace/rasa/stack/assets/productsDomain/seed/IssuanceTestData.xml
# {'T3JkZXJIZWFkZXI6REVNTzgxMDE1': values {
#   key: "createdBy"
#   value: "admin"
# }
# values {
#   key: "currencyUom"
#   value: "USD"
# }
# values {
#   key: "entryDate"
#   value: "2011-08-12 23:17:11.507"
# }
# values {
#   key: "grandTotal"
#   value: "105.14"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderTypeId"
#   value: "SALES_ORDER"
# }
# values {
#   key: "priority"
#   value: "2"
# }
# values {
#   key: "productStoreId"
#   value: "9000"
# }
# values {
#   key: "remainingSubTotal"
#   value: "79.56"
# }
# values {
#   key: "salesChannelEnumId"
#   value: "WEB_SALES_CHANNEL"
# }
# values {
#   key: "statusId"
#   value: "ORDER_APPROVED"
# }
# values {
#   key: "visitId"
#   value: "10043"
# }
# entityName: "OrderHeader"
# , 'T3JkZXJJdGVtOkRFTU84MTAxNeKWqzAwMDAx': values {
#   key: "changeByUserLoginId"
#   value: "admin"
# }
# values {
#   key: "isModifiedPrice"
#   value: "N"
# }
# values {
#   key: "isPromo"
#   value: "N"
# }
# values {
#   key: "itemDescription"
#   value: "Round Gizmo"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "orderItemTypeId"
#   value: "PRODUCT_ORDER_ITEM"
# }
# values {
#   key: "prodCatalogId"
#   value: "DemoCatalog"
# }
# values {
#   key: "productId"
#   value: "GZ-2644"
# }
# values {
#   key: "quantity"
#   value: "6.000000"
# }
# values {
#   key: "selectedAmount"
#   value: "0.000000"
# }
# values {
#   key: "statusId"
#   value: "ITEM_APPROVED"
# }
# values {
#   key: "unitListPrice"
#   value: "48.000"
# }
# values {
#   key: "unitPrice"
#   value: "38.400"
# }
# entityName: "OrderItem"
# , 'T3JkZXJDb250YWN0TWVjaDpERU1PODEwMTXilqtPUkRFUl9FTUFJTOKWqzkwMjE=': values {
#   key: "contactMechId"
#   value: "9021"
# }
# values {
#   key: "contactMechPurposeTypeId"
#   value: "ORDER_EMAIL"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# entityName: "OrderContactMech"
# , 'T3JkZXJDb250YWN0TWVjaDpERU1PODEwMTXilqtTSElQUElOR19MT0NBVElPTuKWqzkwMTA=': values {
#   key: "contactMechId"
#   value: "9010"
# }
# values {
#   key: "contactMechPurposeTypeId"
#   value: "SHIPPING_LOCATION"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# entityName: "OrderContactMech"
# , 'T3JkZXJSb2xlOkRFTU84MTAxNeKWq0NvbXBhbnnilqtCSUxMX0ZST01fVkVORE9S': values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "partyId"
#   value: "Company"
# }
# values {
#   key: "roleTypeId"
#   value: "BILL_FROM_VENDOR"
# }
# entityName: "OrderRole"
# , 'T3JkZXJSb2xlOkRFTU84MTAxNeKWq0RlbW9DdXN0b21lcuKWq0JJTExfVE9fQ1VTVE9NRVI=': values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "partyId"
#   value: "DemoCustomer"
# }
# values {
#   key: "roleTypeId"
#   value: "BILL_TO_CUSTOMER"
# }
# entityName: "OrderRole"
# , 'T3JkZXJSb2xlOkRFTU84MTAxNeKWq0RlbW9DdXN0b21lcuKWq0VORF9VU0VSX0NVU1RPTUVS': values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "partyId"
#   value: "DemoCustomer"
# }
# values {
#   key: "roleTypeId"
#   value: "END_USER_CUSTOMER"
# }
# entityName: "OrderRole"
# , 'T3JkZXJSb2xlOkRFTU84MTAxNeKWq0RlbW9DdXN0b21lcuKWq1BMQUNJTkdfQ1VTVE9NRVI=': values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "partyId"
#   value: "DemoCustomer"
# }
# values {
#   key: "roleTypeId"
#   value: "PLACING_CUSTOMER"
# }
# entityName: "OrderRole"
# , 'T3JkZXJSb2xlOkRFTU84MTAxNeKWq0RlbW9DdXN0b21lcuKWq1NISVBfVE9fQ1VTVE9NRVI=': values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "partyId"
#   value: "DemoCustomer"
# }
# values {
#   key: "roleTypeId"
#   value: "SHIP_TO_CUSTOMER"
# }
# entityName: "OrderRole"
# , 'T3JkZXJQYXltZW50UHJlZmVyZW5jZToxMDAyMA==': values {
#   key: "createdByUserLogin"
#   value: "admin"
# }
# values {
#   key: "createdDate"
#   value: "2011-08-12 23:17:11.789"
# }
# values {
#   key: "maxAmount"
#   value: "105.14"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderPaymentPreferenceId"
#   value: "10020"
# }
# values {
#   key: "overflowFlag"
#   value: "N"
# }
# values {
#   key: "paymentMethodTypeId"
#   value: "EXT_OFFLINE"
# }
# values {
#   key: "presentFlag"
#   value: "N"
# }
# values {
#   key: "statusId"
#   value: "PAYMENT_NOT_RECEIVED"
# }
# values {
#   key: "swipedFlag"
#   value: "N"
# }
# entityName: "OrderPaymentPreference"
# , 'T3JkZXJJdGVtU2hpcEdyb3VwOkRFTU84MTAxNeKWqzAwMDAx': values {
#   key: "carrierPartyId"
#   value: "UPS"
# }
# values {
#   key: "carrierRoleTypeId"
#   value: "CARRIER"
# }
# values {
#   key: "contactMechId"
#   value: "9010"
# }
# values {
#   key: "isGift"
#   value: "N"
# }
# values {
#   key: "maySplit"
#   value: "N"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "00001"
# }
# values {
#   key: "shipmentMethodTypeId"
#   value: "NEXT_DAY"
# }
# entityName: "OrderItemShipGroup"
# , 'T3JkZXJJdGVtU2hpcEdyb3VwQXNzb2M6REVNTzgxMDE14parMDAwMDHilqswMDAwMQ==': values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "quantity"
#   value: "6.000000"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "00001"
# }
# entityName: "OrderItemShipGroupAssoc"
# , 'T3JkZXJBZGp1c3RtZW50OjgxMDE1': values {
#   key: "amount"
#   value: "-8.840"
# }
# values {
#   key: "createdByUserLogin"
#   value: "admin"
# }
# values {
#   key: "createdDate"
#   value: "2011-08-12 23:17:11.708"
# }
# values {
#   key: "description"
#   value: "10% off entire purchase"
# }
# values {
#   key: "orderAdjustmentId"
#   value: "81015"
# }
# values {
#   key: "orderAdjustmentTypeId"
#   value: "PROMOTION_ADJUSTMENT"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "_NA_"
# }
# values {
#   key: "productPromoActionSeqId"
#   value: "01"
# }
# values {
#   key: "productPromoId"
#   value: "9011"
# }
# values {
#   key: "productPromoRuleId"
#   value: "01"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "_NA_"
# }
# entityName: "OrderAdjustment"
# , 'T3JkZXJBZGp1c3RtZW50OjgxMDE2': values {
#   key: "amount"
#   value: "-103.600"
# }
# values {
#   key: "createdByUserLogin"
#   value: "admin"
# }
# values {
#   key: "createdDate"
#   value: "2011-08-12 23:17:11.708"
# }
# values {
#   key: "description"
#   value: "Buy 4 items for $50 from Purple Gizmo [GZ-5005], Rainbow Gizmo [GZ-1004], Round Gizmo [GZ-2644] or Square Gizmo [GZ-2002] limit 2 per customer"
# }
# values {
#   key: "orderAdjustmentId"
#   value: "81016"
# }
# values {
#   key: "orderAdjustmentTypeId"
#   value: "PROMOTION_ADJUSTMENT"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "productPromoActionSeqId"
#   value: "01"
# }
# values {
#   key: "productPromoId"
#   value: "9015"
# }
# values {
#   key: "productPromoRuleId"
#   value: "01"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "_NA_"
# }
# entityName: "OrderAdjustment"
# , 'T3JkZXJBZGp1c3RtZW50OjgxMDE3': values {
#   key: "amount"
#   value: "-38.400"
# }
# values {
#   key: "createdByUserLogin"
#   value: "admin"
# }
# values {
#   key: "createdDate"
#   value: "2011-08-12 23:17:11.708"
# }
# values {
#   key: "description"
#   value: "Get $500 off any item in the Small Gizmos [101] category, limit 1 per order, 2 per customer, 3 for entire promotion. Discount not to exceed the price of the item."
# }
# values {
#   key: "orderAdjustmentId"
#   value: "81017"
# }
# values {
#   key: "orderAdjustmentTypeId"
#   value: "PROMOTION_ADJUSTMENT"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "productPromoActionSeqId"
#   value: "01"
# }
# values {
#   key: "productPromoId"
#   value: "9016"
# }
# values {
#   key: "productPromoRuleId"
#   value: "01"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "_NA_"
# }
# entityName: "OrderAdjustment"
# , 'T3JkZXJBZGp1c3RtZW50OjgxMDE4': values {
#   key: "amount"
#   value: "24.700"
# }
# values {
#   key: "createdByUserLogin"
#   value: "admin"
# }
# values {
#   key: "createdDate"
#   value: "2011-08-12 23:17:11.708"
# }
# values {
#   key: "orderAdjustmentId"
#   value: "81018"
# }
# values {
#   key: "orderAdjustmentTypeId"
#   value: "SHIPPING_CHARGES"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "_NA_"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "00001"
# }
# entityName: "OrderAdjustment"
# , 'T3JkZXJBZGp1c3RtZW50OjgxMDE5': values {
#   key: "amount"
#   value: "0.000"
# }
# values {
#   key: "comments"
#   value: "Utah County, Utah Sales Tax"
# }
# values {
#   key: "createdByUserLogin"
#   value: "admin"
# }
# values {
#   key: "createdDate"
#   value: "2011-08-12 23:17:11.708"
# }
# values {
#   key: "customerReferenceId"
#   value: "12-3456789"
# }
# values {
#   key: "exemptAmount"
#   value: "0.00"
# }
# values {
#   key: "orderAdjustmentId"
#   value: "81019"
# }
# values {
#   key: "orderAdjustmentTypeId"
#   value: "SALES_TAX"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "_NA_"
# }
# values {
#   key: "overrideGlAccountId"
#   value: "224153"
# }
# values {
#   key: "primaryGeoId"
#   value: "UT-UTAH"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "00001"
# }
# values {
#   key: "sourcePercentage"
#   value: "0.100000"
# }
# values {
#   key: "taxAuthGeoId"
#   value: "UT-UTAH"
# }
# values {
#   key: "taxAuthPartyId"
#   value: "UT_UTAH_TAXMAN"
# }
# values {
#   key: "taxAuthorityRateSeqId"
#   value: "9005"
# }
# entityName: "OrderAdjustment"
# , 'T3JkZXJBZGp1c3RtZW50OjgxMDIw': values {
#   key: "amount"
#   value: "0.000"
# }
# values {
#   key: "comments"
#   value: "Utah County, Utah Sales Tax"
# }
# values {
#   key: "createdByUserLogin"
#   value: "admin"
# }
# values {
#   key: "createdDate"
#   value: "2011-08-12 23:17:11.708"
# }
# values {
#   key: "customerReferenceId"
#   value: "12-3456789"
# }
# values {
#   key: "exemptAmount"
#   value: "0.08"
# }
# values {
#   key: "orderAdjustmentId"
#   value: "81020"
# }
# values {
#   key: "orderAdjustmentTypeId"
#   value: "SALES_TAX"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "overrideGlAccountId"
#   value: "224153"
# }
# values {
#   key: "primaryGeoId"
#   value: "UT-UTAH"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "00001"
# }
# values {
#   key: "sourcePercentage"
#   value: "0.100000"
# }
# values {
#   key: "taxAuthGeoId"
#   value: "UT-UTAH"
# }
# values {
#   key: "taxAuthPartyId"
#   value: "UT_UTAH_TAXMAN"
# }
# values {
#   key: "taxAuthorityRateSeqId"
#   value: "9005"
# }
# entityName: "OrderAdjustment"
# , 'T3JkZXJBZGp1c3RtZW50OjgxMDIx': values {
#   key: "amount"
#   value: "0.000"
# }
# values {
#   key: "comments"
#   value: "Utah State Sales Tax"
# }
# values {
#   key: "createdByUserLogin"
#   value: "admin"
# }
# values {
#   key: "createdDate"
#   value: "2011-08-12 23:17:11.708"
# }
# values {
#   key: "customerReferenceId"
#   value: "12-3456789"
# }
# values {
#   key: "exemptAmount"
#   value: "4.19"
# }
# values {
#   key: "orderAdjustmentId"
#   value: "81021"
# }
# values {
#   key: "orderAdjustmentTypeId"
#   value: "SALES_TAX"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "overrideGlAccountId"
#   value: "224153"
# }
# values {
#   key: "primaryGeoId"
#   value: "UT"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "00001"
# }
# values {
#   key: "sourcePercentage"
#   value: "4.750000"
# }
# values {
#   key: "taxAuthGeoId"
#   value: "UT"
# }
# values {
#   key: "taxAuthPartyId"
#   value: "UT_TAXMAN"
# }
# values {
#   key: "taxAuthorityRateSeqId"
#   value: "9004"
# }
# entityName: "OrderAdjustment"
# , 'T3JkZXJBZGp1c3RtZW50OjgxMDIy': values {
#   key: "amount"
#   value: "0.884"
# }
# values {
#   key: "comments"
#   value: "1% OFB _NA_ Tax"
# }
# values {
#   key: "createdByUserLogin"
#   value: "admin"
# }
# values {
#   key: "createdDate"
#   value: "2011-08-12 23:17:11.708"
# }
# values {
#   key: "orderAdjustmentId"
#   value: "81022"
# }
# values {
#   key: "orderAdjustmentTypeId"
#   value: "SALES_TAX"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "overrideGlAccountId"
#   value: "224000"
# }
# values {
#   key: "primaryGeoId"
#   value: "_NA_"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "00001"
# }
# values {
#   key: "sourcePercentage"
#   value: "1.000000"
# }
# values {
#   key: "taxAuthGeoId"
#   value: "_NA_"
# }
# values {
#   key: "taxAuthPartyId"
#   value: "_NA_"
# }
# values {
#   key: "taxAuthorityRateSeqId"
#   value: "9000"
# }
# entityName: "OrderAdjustment"
# , 'T3JkZXJTdGF0dXM6ODEwMTU=': values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderStatusId"
#   value: "81015"
# }
# values {
#   key: "statusDatetime"
#   value: "2011-08-12 23:17:11.507"
# }
# values {
#   key: "statusId"
#   value: "ORDER_CREATED"
# }
# values {
#   key: "statusUserLogin"
#   value: "admin"
# }
# entityName: "OrderStatus"
# , 'T3JkZXJTdGF0dXM6ODEwMTY=': values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "orderStatusId"
#   value: "81016"
# }
# values {
#   key: "statusDatetime"
#   value: "2011-08-12 23:17:11.507"
# }
# values {
#   key: "statusId"
#   value: "ITEM_CREATED"
# }
# values {
#   key: "statusUserLogin"
#   value: "admin"
# }
# entityName: "OrderStatus"
# , 'SW52ZW50b3J5SXRlbURldGFpbDo5MDAx4parODEwMTU=': values {
#   key: "accountingQuantityDiff"
#   value: "0.000000"
# }
# values {
#   key: "availableToPromiseDiff"
#   value: "-5.000000"
# }
# values {
#   key: "effectiveDate"
#   value: "2011-08-12 23:17:12.433"
# }
# values {
#   key: "inventoryItemDetailSeqId"
#   value: "81015"
# }
# values {
#   key: "inventoryItemId"
#   value: "9001"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "quantityOnHandDiff"
#   value: "0.000000"
# }
# entityName: "InventoryItemDetail"
# , 'SW52ZW50b3J5SXRlbURldGFpbDo5MDI14parODEwMTY=': values {
#   key: "accountingQuantityDiff"
#   value: "0.000000"
# }
# values {
#   key: "availableToPromiseDiff"
#   value: "-1.000000"
# }
# values {
#   key: "effectiveDate"
#   value: "2011-08-12 23:17:12.85"
# }
# values {
#   key: "inventoryItemDetailSeqId"
#   value: "81016"
# }
# values {
#   key: "inventoryItemId"
#   value: "9025"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "quantityOnHandDiff"
#   value: "0.000000"
# }
# entityName: "InventoryItemDetail"
# , 'T3JkZXJJdGVtU2hpcEdycEludlJlczpERU1PODEwMTXilqswMDAwMeKWqzAwMDAx4parOTAwMQ==': values {
#   key: "createdDatetime"
#   value: "2011-08-12 23:17:12.839"
# }
# values {
#   key: "inventoryItemId"
#   value: "9001"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "priority"
#   value: "2"
# }
# values {
#   key: "promisedDatetime"
#   value: "2011-08-27 23:17:11.507"
# }
# values {
#   key: "quantity"
#   value: "5.000000"
# }
# values {
#   key: "reserveOrderEnumId"
#   value: "INVRO_FIFO_REC"
# }
# values {
#   key: "reservedDatetime"
#   value: "2011-08-12 23:17:12.839"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "00001"
# }
# entityName: "OrderItemShipGrpInvRes"
# , 'T3JkZXJJdGVtU2hpcEdycEludlJlczpERU1PODEwMTXilqswMDAwMeKWqzAwMDAx4parOTAyNQ==': values {
#   key: "createdDatetime"
#   value: "2011-08-12 23:17:12.967"
# }
# values {
#   key: "inventoryItemId"
#   value: "9025"
# }
# values {
#   key: "orderId"
#   value: "DEMO81015"
# }
# values {
#   key: "orderItemSeqId"
#   value: "00001"
# }
# values {
#   key: "priority"
#   value: "2"
# }
# values {
#   key: "promisedDatetime"
#   value: "2011-08-27 23:17:11.507"
# }
# values {
#   key: "quantity"
#   value: "1.000000"
# }
# values {
#   key: "reserveOrderEnumId"
#   value: "INVRO_FIFO_REC"
# }
# values {
#   key: "reservedDatetime"
#   value: "2011-08-12 23:17:12.967"
# }
# values {
#   key: "shipGroupSeqId"
#   value: "00001"
# }
# entityName: "OrderItemShipGrpInvRes"
# }
# ['T3JkZXJIZWFkZXI6REVNTzgxMDE1', 'T3JkZXJJdGVtOkRFTU84MTAxNeKWqzAwMDAx', 'T3JkZXJDb250YWN0TWVjaDpERU1PODEwMTXilqtPUkRFUl9FTUFJTOKWqzkwMjE=', 'T3JkZXJDb250YWN0TWVjaDpERU1PODEwMTXilqtTSElQUElOR19MT0NBVElPTuKWqzkwMTA=', 'T3JkZXJSb2xlOkRFTU84MTAxNeKWq0NvbXBhbnnilqtCSUxMX0ZST01fVkVORE9S', 'T3JkZXJSb2xlOkRFTU84MTAxNeKWq0RlbW9DdXN0b21lcuKWq0JJTExfVE9fQ1VTVE9NRVI=', 'T3JkZXJSb2xlOkRFTU84MTAxNeKWq0RlbW9DdXN0b21lcuKWq0VORF9VU0VSX0NVU1RPTUVS', 'T3JkZXJSb2xlOkRFTU84MTAxNeKWq0RlbW9DdXN0b21lcuKWq1BMQUNJTkdfQ1VTVE9NRVI=', 'T3JkZXJSb2xlOkRFTU84MTAxNeKWq0RlbW9DdXN0b21lcuKWq1NISVBfVE9fQ1VTVE9NRVI=', 'T3JkZXJQYXltZW50UHJlZmVyZW5jZToxMDAyMA==', 'T3JkZXJJdGVtU2hpcEdyb3VwOkRFTU84MTAxNeKWqzAwMDAx', 'T3JkZXJJdGVtU2hpcEdyb3VwQXNzb2M6REVNTzgxMDE14parMDAwMDHilqswMDAwMQ==', 'T3JkZXJBZGp1c3RtZW50OjgxMDE1', 'T3JkZXJBZGp1c3RtZW50OjgxMDE2', 'T3JkZXJBZGp1c3RtZW50OjgxMDE3', 'T3JkZXJBZGp1c3RtZW50OjgxMDE4', 'T3JkZXJBZGp1c3RtZW50OjgxMDE5', 'T3JkZXJBZGp1c3RtZW50OjgxMDIw', 'T3JkZXJBZGp1c3RtZW50OjgxMDIx', 'T3JkZXJBZGp1c3RtZW50OjgxMDIy', 'T3JkZXJTdGF0dXM6ODEwMTU=', 'T3JkZXJTdGF0dXM6ODEwMTY=', 'SW52ZW50b3J5SXRlbURldGFpbDo5MDAx4parODEwMTU=', 'SW52ZW50b3J5SXRlbURldGFpbDo5MDI14parODEwMTY=', 'T3JkZXJJdGVtU2hpcEdycEludlJlczpERU1PODEwMTXilqswMDAwMeKWqzAwMDAx4parOTAwMQ==', 'T3JkZXJJdGVtU2hpcEdycEludlJlczpERU1PODEwMTXilqswMDAwMeKWqzAwMDAx4parOTAyNQ==']

# %%
f=os.path.join(build_dir, 'last_modify.json')
base=os.path.basename(f)
print(base)
# Out:
# last_modify.json

# %%
import io_utils
import json_utils

last_mods={}
for f in io_utils.list_files(asset_dir):
    print(os.path.getmtime(f))
    base=os.path.basename(f)
    last_mods[base]=os.path.getmtime(f)

modify_recs=os.path.join(build_dir, 'last_modify.json')
print(modify_recs)
json_utils.write_json_to_file(modify_recs, last_mods)
# Out:
# 1553238689.0159047
# 1553274405.6859667
# 1553238689.0164716
# ./assets/productsDomain/build/last_modify.json

# %%
recs=json_utils.read_json_file(modify_recs)
for k,v in recs.items():
    print(k,v)
# Out:
# ProductPriceTestData.xml 1553238689.0159047
# IssuanceTestData.xml 1553274405.6859667
# ProductTestData.xml 1553238689.0164716

# %%
modified_set=[]
for f in io_utils.list_files(asset_dir):
    dt=os.path.getmtime(f)
    print(dt)
    base=os.path.basename(f)
    if base in recs:
        if dt>recs[base]:
            print('file %s modified'%base)
            modified_set.append(base)
    else:
        # is new file
        modified_set.append(base)

print('modified files:', modified_set)
# Out:
# 1553276887.9454908
# file ProductPriceTestData.xml modified
# 1553274405.6859667
# 1553238689.0164716
# modified files: ['ProductPriceTestData.xml']
