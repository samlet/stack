# %%
from sagas.nlu.uni_remote_viz import viz_sample
viz_sample('he', '‫היכן נמצא סניף הדואר הקרוב?‬')
# Out:
# .. request is {'lang': 'he', 'sents': '\u202bהיכן נמצא סניף הדואר הקרוב?\u202c', 'engine': 'corenlp', 'pipelines': ['predicts']}
# words count 9
# ✁ chunks. -------------------------
# ❶ verb_domains(נמצא) _
#      rel index  text lemma                  children            features
# 0    obl     2  היכן  היכן                 [ל, היכן]      [c_adv, x_adv]
# 1  nsubj     4  סניף  סניף  [סניף, ה, דואר, ה, קרוב]    [c_noun, x_noun]
# 2  punct     9     ?     ?                       [?]  [c_punct, x_punct]
# obl -> ל היכן
# nsubj -> סניף ה דואר ה קרוב
# ✁ dependency-graph. -------------------------
#   index  text lemma   upos   xpos
# 0     1     ל     ל    ADP    ADP
# 1     2  היכן  היכן    ADV    ADV
# 2     3  נמצא  נמצא   VERB   VERB
# 3     4  סניף  סניף   NOUN   NOUN
# 4     5     ה     ה    DET    DET
# 5     6  דואר  דואר   NOUN   NOUN
# 6     7     ה     ה    DET    DET
# 7     8  קרוב  קרוב    ADJ    ADJ
# 8     9     ?     ?  PUNCT  PUNCT

# %%
import sagas
he=lambda s: sagas.dia('he', local_translit=True).ana(s)
he('‫היכן נמצא סניף הדואר הקרוב?‬')
# Out:
# Where is the nearest post office?
# ♡  aichn nmca snif adoar akrov
# text: ל 	lemma: ל	upos: ADP	xpos: ADP
# text: היכן 	lemma: היכן	upos: ADV	xpos: ADV
# text: נמצא 	lemma: נמצא	upos: VERB	xpos: VERB
# text: סניף 	lemma: סניף	upos: NOUN	xpos: NOUN
# text: ה 	lemma: ה	upos: DET	xpos: DET
# text: דואר 	lemma: דואר	upos: NOUN	xpos: NOUN
# text: ה 	lemma: ה	upos: DET	xpos: DET
# text: קרוב 	lemma: קרוב	upos: ADJ	xpos: ADJ
# text: ? 	lemma: ?	upos: PUNCT	xpos: PUNCT
# text: ‬ 	lemma: ‬	upos: PUNCT	xpos: PUNCT
# ('ל', '2', 'case')
# ('היכן', '3', 'obl')
# ('נמצא', '0', 'root')
# ('סניף', '3', 'nsubj')
# ('ה', '6', 'det:def')
# ('דואר', '4', 'compound:smixut')
# ('ה', '8', 'det:def')
# ('קרוב', '4', 'amod')
# ('?', '3', 'punct')

# %%
# https://www.goethe-verlag.com/book2/ZH/ZHHE/ZHHE061.HTM
