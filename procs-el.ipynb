# %%
import sagas
alphabet='''Α α	άλφα	álpha	[a]
Β β	βήτα	bḗta	[v]
Γ γ	γάμμα	gámma	/i/,/e/前为[ʝ]，其余为[ɣ]
Δ δ	δέλτα	délta	[ð]
Ε ε	έψιλον	épsilon	[e]
Ζ ζ	ζήτα	zḗta	[z]
Η η	ήτα	ḗta	[i]
Θ θ	θήτα	thḗta	[θ]
Ι ι	ιώτα	iṓta	[i]
Κ κ	κάππα	káppa	/i/,/e/前为[c]，其余为[k]
Λ λ	λάμδα	lámda	[l]
Μ μ	μυ	my	[m]
Ν ν	νυ	ny	[n]
Ξ ξ	ξι	xi	[ks]
Ο ο	όμικρον	ómikron	[o]
Π π	πι	pi	[p]
Ρ ρ	ρω	rō	[ɾ]
Σ σ为词中／ς为词尾	σίγμα	sígma	[s]
Τ τ	ταυ	tau	[t]
Υ υ	ύψιλον	ýpsilon	[i]
Φ φ	φι	phi	[f]
Χ χ	χι	chi	/i/,/e/前为[ç]，其余为[x]
Ψ ψ	ψι	psi	[ps]
Ω ω	ωμέγα	ōméga	[o]'''.split('\n')
rs=[line.split('\t') for line in alphabet]
sagas.to_df(rs, ['letter', 'name_el', 'name_en','ips' ])
# Out:
#          letter  name_el  name_en                  ips
# 0           Α α     άλφα    álpha                  [a]
# 1           Β β     βήτα     bḗta                  [v]
# 2           Γ γ    γάμμα    gámma  /i/,/e/前为[ʝ]，其余为[ɣ]
# 3           Δ δ    δέλτα    délta                  [ð]
# 4           Ε ε   έψιλον  épsilon                  [e]
# 5           Ζ ζ     ζήτα     zḗta                  [z]
# 6           Η η      ήτα      ḗta                  [i]
# 7           Θ θ     θήτα    thḗta                  [θ]
# 8           Ι ι     ιώτα     iṓta                  [i]
# 9           Κ κ    κάππα    káppa  /i/,/e/前为[c]，其余为[k]
# 10          Λ λ    λάμδα    lámda                  [l]
# 11          Μ μ       μυ       my                  [m]
# 12          Ν ν       νυ       ny                  [n]
# 13          Ξ ξ       ξι       xi                 [ks]
# 14          Ο ο  όμικρον  ómikron                  [o]
# 15          Π π       πι       pi                  [p]
# ...

# %%
import sagas
sagas.dia('el').ana_s('Η σαλάτα έχει ελαιόλαδο.')
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/pi/ai/corenlp/el_gdt_models/el_gdt_tokenizer.pt', 'lang': 'el', 'shorthand': 'el_gdt', 'mode': 'predict'}
# ---
# Loading: mwt
# With settings:
# {'model_path': '/pi/ai/corenlp/el_gdt_models/el_gdt_mwt_expander.pt', 'lang': 'el', 'shorthand': 'el_gdt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# ---
# Loading: pos
# With settings:
# {'model_path': '/pi/ai/corenlp/el_gdt_models/el_gdt_tagger.pt', 'pretrain_path': '/pi/ai/corenlp/el_gdt_models/el_gdt.pretrain.pt', 'lang': 'el', 'shorthand': 'el_gdt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/pi/ai/corenlp/el_gdt_models/el_gdt_lemmatizer.pt', 'lang': 'el', 'shorthand': 'el_gdt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# ...

# %%
sagas.dia('el').ana('Η σαλάτα έχει ελαιόλαδο.')
# Out:
# text: Η 	lemma: ο	upos: DET	xpos: DET
# text: σαλάτα 	lemma: σαλάτα	upos: NOUN	xpos: NOUN
# text: έχει 	lemma: έχω	upos: VERB	xpos: VERB
# text: ελαιόλαδο 	lemma: ελαιόλαδος	upos: NOUN	xpos: NOUN
# text: . 	lemma: .	upos: PUNCT	xpos: PUNCT
# ('Η', '2', 'det')
# ('σαλάτα', '3', 'nsubj')
# ('έχει', '0', 'root')
# ('ελαιόλαδο', '3', 'obj')
# ('.', '3', 'punct')
