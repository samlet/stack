# %%
from sagas.nlu.corenlp_helper import CoreNlp, CoreNlpViz, LangDialect, get_nlp
LangDialect('cs').ana('To nejsou muži.')
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/pi/ai/corenlp/cs_pdt_models/cs_pdt_tokenizer.pt', 'lang': 'cs', 'shorthand': 'cs_pdt', 'mode': 'predict'}
# ---
# Loading: mwt
# With settings:
# {'model_path': '/pi/ai/corenlp/cs_pdt_models/cs_pdt_mwt_expander.pt', 'lang': 'cs', 'shorthand': 'cs_pdt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# ---
# Loading: pos
# With settings:
# {'model_path': '/pi/ai/corenlp/cs_pdt_models/cs_pdt_tagger.pt', 'pretrain_path': '/pi/ai/corenlp/cs_pdt_models/cs_pdt.pretrain.pt', 'lang': 'cs', 'shorthand': 'cs_pdt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/pi/ai/corenlp/cs_pdt_models/cs_pdt_lemmatizer.pt', 'lang': 'cs', 'shorthand': 'cs_pdt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# ...

# %%
LangDialect('cs').ana('Moje společnost chce vyrábět nástroje.')
# Out:
# text: Moje 	lemma: můj	upos: DET	xpos: PSHS1-S1-------
# text: společnost 	lemma: společnost	upos: NOUN	xpos: NNFS1-----A----
# text: chce 	lemma: chtít	upos: VERB	xpos: VB-S---3P-AA---
# text: vyrábět 	lemma: vyrábět	upos: VERB	xpos: Vf--------A----
# text: nástroje 	lemma: nástroj	upos: NOUN	xpos: NNIP4-----A----
# text: . 	lemma: .	upos: PUNCT	xpos: Z:-------------
# ('Moje', '2', 'det')
# ('společnost', '3', 'nsubj')
# ('chce', '0', 'root')
# ('vyrábět', '3', 'xcomp')
# ('nástroje', '4', 'obj')
# ('.', '3', 'punct')

# %%
LangDialect('ru').ana('Моя компания хочет производить инструменты.')
# Out:
# text: Моя 	lemma: мой	upos: DET	xpos: _
# text: компания 	lemma: компания	upos: NOUN	xpos: _
# text: хочет 	lemma: хотеть	upos: VERB	xpos: _
# text: производить 	lemma: производить	upos: VERB	xpos: _
# text: инструменты 	lemma: инструмент	upos: NOUN	xpos: _
# text: . 	lemma: .	upos: PUNCT	xpos: _
# ('Моя', '2', 'det')
# ('компания', '3', 'nsubj')
# ('хочет', '0', 'root')
# ('производить', '3', 'xcomp')
# ('инструменты', '4', 'obj')
# ('.', '3', 'punct')
