# %%
from sagas.nlu.uni_remote_viz import viz_sample
# from sagas.nlu.transliterations import translits
import kroman

# en="List the files you edited last week."
sents='지난 주에 편집 한 파일을 나열하십시오.'
tr=kroman.parse(sents)
print(tr.replace('-',''))
viz_sample('ko', sents, 'corenlp')
# Out:
# jinan jue pyeonjib han paireur nayeorhasibsio.
# .. request is {'lang': 'ko', 'sents': '지난 주에 편집 한 파일을 나열하십시오.', 'engine': 'corenlp', 'pipelines': ['predicts']}
# words count 7
# ✁ chunks. -------------------------
# ❶ verb_domains(지나+ㄴ) _
# Empty DataFrame
# Columns: [rel, index, text, lemma, children, features]
# Index: []
# ❷ verb_domains(나열+하+시+ㅂ시오) _
#      rel index text lemma      children             features
# 0    obl     2   주에   주+에      [지난, 주에]   [c_adv, x_ncn+jca]
# 1    obj     5  파일을  파일+을  [편집, 한, 파일을]  [c_noun, x_ncn+jco]
# 2  punct     7    .     .           [.]      [c_punct, x_sf]
# obl -> 지나+ㄴ 주+에
# obj -> 편집 한 파일+을
# ✁ dependency-graph. -------------------------
#   index    text       lemma   upos            xpos
# 0     1      지난        지나+ㄴ   VERB         pvg+etm
# 1     2      주에         주+에    ADV         ncn+jca
# 2     3      편집          편집   NOUN             ncn
# 3     4       한           한    NUM             nnc
# ...
