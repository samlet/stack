# %%
from sagas.nlu.uni_remote_viz import viz_sample
viz_sample('en', 'Mr.Victor came to our classroom to have a talk with us last week.')
# Out:
# .. request is {'lang': 'en', 'sents': 'Mr.Victor came to our classroom to have a talk with us last week.', 'engine': 'corenlp', 'pipelines': ['predicts']}
# words count 14
# ✁ chunks. -------------------------
# ❶ verb_domains(come) _
#      rel index       text      lemma  \
# 0  nsubj     1  Mr.Victor  Mr.Victor
# 1    obl     5  classroom  classroom
# 2  advcl     7       have       have
# 3  punct    14          .          .
#
#                                     children          features
# 0                                [Mr.Victor]  [c_propn, x_nnp]
# 1                       [to, our, classroom]    [c_noun, x_nn]
# 2  [to, have, a, talk, with, us, last, week]    [c_verb, x_vb]
# 3                                        [.]    [c_punct, x_.]
# obl -> to we classroom
# advcl -> to have a talk with we last week
# ❷ verb_domains(have) _
#         rel index  text lemma             children        features
# 0      mark     6    to    to                 [to]  [c_part, x_to]
# ...

# %%
viz_sample('en', "List the files edited last week.")
# Out:
# .. request is {'lang': 'en', 'sents': 'List the files edited last week.', 'engine': 'corenlp', 'pipelines': ['predicts']}
# words count 7
# ✁ chunks. -------------------------
# ❶ verb_domains(list) _
#      rel index   text lemma                          children         features
# 0    obj     3  files  file  [the, files, edited, last, week]  [c_noun, x_nns]
# 1  punct     7      .     .                               [.]   [c_punct, x_.]
# obj -> the file edite last week
# ❷ verb_domains(edite) _
#         rel index  text lemma      children        features
# 0  obl:tmod     6  week  week  [last, week]  [c_noun, x_nn]
# obl:tmod -> last week
# ✁ dependency-graph. -------------------------
#   index    text  lemma   upos xpos
# 0     1    List   list   VERB   VB
# 1     2     the    the    DET   DT
# 2     3   files   file   NOUN  NNS
# 3     4  edited  edite   VERB  VBN
# 4     5    last   last    ADJ   JJ
# 5     6    week   week   NOUN   NN
# 6     7       .      .  PUNCT    .

# %%
viz_sample('en', 'Victor came to our classroom to have a talk with us last week.', 'spacy')
# Out:
# .. request is {'lang': 'en', 'sents': 'Victor came to our classroom to have a talk with us last week.', 'engine': 'spacy'}
# words count 14
# ❶ verb_domains(come) _
#      rel  index    text   lemma                                   children  \
# 0  nsubj      1  Victor  Victor                                   [Victor]
# 1   prep      3      to      to                       [to, our, classroom]
# 2  advcl      7    have    have  [to, have, a, talk, with, us, last, week]
# 3  punct     14       .       .                                        [.]
#
#            features
# 0  [c_propn, x_nnp]
# 1     [c_adp, x_in]
# 2    [c_verb, x_vb]
# 3    [c_punct, x_.]
# prep -> to -PRON- classroom
# advcl -> to have a talk with -PRON- last week
# ❷ verb_domains(have) _
#         rel  index  text lemma             children        features
# 0       aux      6    to    to                 [to]  [c_part, x_to]
# 1      dobj      9  talk  talk  [a, talk, with, us]  [c_noun, x_nn]
# ...
