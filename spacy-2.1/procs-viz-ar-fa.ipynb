# %%
from sagas.nlu.uni_remote_viz import viz_sample
viz_sample('ar', "جارَك عُمَر مُتَرْجِم يا رَواد.")
# Out:
# .. request is {'lang': 'ar', 'sents': 'جارَك عُمَر مُتَرْجِم يا رَواد.', 'engine': 'corenlp', 'pipelines': ['predicts']}
# words count 7
#   index    text       lemma   upos        xpos
# 0     1   جارَك     جَارِئك      X  U---------
# 1     2   عُمَر       عُمَر      X  U---------
# 2     3  متبرصج  مُتَبَرِّص      X  U---------
# 3     4      جم          جم      X  U---------
# 4     5      يا         يَا      X  U---------
# 5     6   رَواد       رَواد      X  U---------
# 6     7       .           .  PUNCT  G---------

# %%
viz_sample('ar', 'جارك رجل طيب')
# Out:
# .. request is {'lang': 'ar', 'sents': 'جارك رجل طيب', 'engine': 'corenlp', 'pipelines': ['predicts']}
# words count 3
#   index  text   lemma  upos        xpos
# 0     1  جارك  جَارَك     X  U---------
# 1     2   رجل   رَجُل  NOUN  N------S2I
# 2     3   طيب     طيب     X  U---------

# %%
viz_sample('ar', 'أنا طالب جامعي صيني')
# Out:
# .. request is {'lang': 'ar', 'sents': 'أنا طالب جامعي صيني', 'engine': 'corenlp', 'pipelines': ['predicts']}
# words count 4
# ❶ subj_domains(هُوَ) طالب(noun)
#      rel index   text      lemma children                features
# 0  nsubj     1    أنا       هُوَ    [أنا]  [c_pron, x_sp---2ms1-]
# 1   amod     3  جامعي  جَامِعِيّ  [جامعي]   [c_adj, x_a-----ms1i]
# 2   amod     4   صيني    صِينِيّ   [صيني]   [c_adj, x_a-----ms2i]
# {'predicts': []}
#   index   text      lemma  upos        xpos
# 0     1    أنا       هُوَ  PRON  SP---2MS1-
# 1     2   طالب     طَالِب  NOUN  N------S1I
# 2     3  جامعي  جَامِعِيّ   ADJ  A-----MS1I
# 3     4   صيني    صِينِيّ   ADJ  A-----MS2I

# %%
import sagas
sagas.dia('ar').ana("جارَك عُمَر مُتَرْجِم يا رَواد.")
# Out:
# Your neighbor Omar is an interpreter, pioneers.
# text: جارَك 	lemma: جَارِئك	upos: X	xpos: U---------
# text: عُمَر 	lemma: عُمَر	upos: X	xpos: U---------
# text: متبرصج 	lemma: مُتَبَرِّص	upos: X	xpos: U---------
# text: جم 	lemma: جم	upos: X	xpos: U---------
# text: يا 	lemma: يَا	upos: X	xpos: U---------
# text: رَواد 	lemma: رَواد	upos: X	xpos: U---------
# text: . 	lemma: .	upos: PUNCT	xpos: G---------
# ('جارَك', '0', 'root')
# ('عُمَر', '1', 'nmod')
# ('متبرصج', '1', 'nmod')
# ('جم', '6', 'nmod')
# ('يا', '6', 'nmod')
# ('رَواد', '1', 'dep')
# ('.', '1', 'punct')

# %%
sagas.dia('fa').ana('واقعا خوب بود.')
# Out:
# It was really good.
# text: واقعا 	lemma: None	upos: ADV	xpos: ADV
# text: خوب 	lemma: خوب	upos: ADJ	xpos: ADJ
# text: بود 	lemma: بود#باش	upos: AUX	xpos: V_PA
# text: . 	lemma: .	upos: PUNCT	xpos: DELM
# ('واقعا', '2', 'advmod')
# ('خوب', '0', 'root')
# ('بود', '2', 'cop')
# ('.', '2', 'punct')

# %%
sagas.dia('fa').ana('برنامه ای برای فردا شب داری؟')
# Out:
# Have a plan for tomorrow night?
# text: برنامه 	lemma: برنامه	upos: NOUN	xpos: N_SING
# text: ای 	lemma: ای	upos: INTJ	xpos: INT
# text: برای 	lemma: برای	upos: ADP	xpos: P
# text: فردا 	lemma: فردا	upos: ADV	xpos: ADV_TIME
# text: شب 	lemma: شب	upos: NOUN	xpos: N_SING
# text: داری 	lemma: داشت#دار	upos: VERB	xpos: V_PRS
# text: ؟ 	lemma: ؟	upos: PUNCT	xpos: DELM
# ('برنامه', '6', 'nsubj')
# ('ای', '6', 'nsubj')
# ('برای', '4', 'case')
# ('فردا', '6', 'advcl')
# ('شب', '6', 'compound:lvc')
# ('داری', '0', 'root')
# ('؟', '6', 'punct')

# %%
viz_sample('fa','برنامه ای برای فردا شب داری؟')
# Out:
# .. request is {'lang': 'fa', 'sents': 'برنامه ای برای فردا شب داری؟', 'engine': 'corenlp', 'pipelines': ['predicts']}
# words count 7
# ❶ verb_domains(داشت#دار) _
#             rel index    text   lemma      children             features
# 0         nsubj     1  برنامه  برنامه      [برنامه]   [c_noun, x_n_sing]
# 1         nsubj     2      ای      ای          [ای]      [c_intj, x_int]
# 2         advcl     4    فردا    فردا  [برای, فردا]  [c_adv, x_adv_time]
# 3  compound:lvc     5      شب      شب          [شب]   [c_noun, x_n_sing]
# 4         punct     7       ؟       ؟           [؟]    [c_punct, x_delm]
# advcl -> برای فردا
# {'predicts': []}
#   index    text     lemma   upos      xpos
# 0     1  برنامه    برنامه   NOUN    N_SING
# 1     2      ای        ای   INTJ       INT
# 2     3    برای      برای    ADP         P
# 3     4    فردا      فردا    ADV  ADV_TIME
# 4     5      شب        شب   NOUN    N_SING
# 5     6    داری  داشت#دار   VERB     V_PRS
# ...

# %%
# import sagas
# sagas.dia('fa').ana('واقعا خوب بود.')
