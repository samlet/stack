# %%
from sagas.nlu.uni_remote_viz import viz_sample
viz_sample('ja', '下鴨神社の参道は暗かった。')
# Out:
# .. request is {'lang': 'ja', 'sents': '下鴨神社の参道は暗かった。', 'engine': 'corenlp'}
# words count 8
# ❶ aux_domains(た) 暗かっ(adj)
#      rel index text lemma            children   features
# 0  nsubj     4   参道    参道  [下鴨, 神社, の, 参道, は]   [c_noun]
# 1    aux     7    た     た                 [た]    [c_aux]
# 2  punct     8    。     。                 [。]  [c_punct]
# nsubj -> 下鴨 神社 の 参道 は
# index: 1	text: 下鴨 	lemma: 下鴨	upos: NOUN	xpos: _
# index: 2	text: 神社 	lemma: 神社	upos: NOUN	xpos: _
# index: 3	text: の 	lemma: の	upos: ADP	xpos: _
# index: 4	text: 参道 	lemma: 参道	upos: NOUN	xpos: _
# index: 5	text: は 	lemma: は	upos: ADP	xpos: _
# index: 6	text: 暗かっ 	lemma: 暗い	upos: ADJ	xpos: _
# index: 7	text: た 	lemma: た	upos: AUX	xpos: _
# index: 8	text: 。 	lemma: 。	upos: PUNCT	xpos: _
# 下鴨 -> compound, 2, 神社
# 神社 -> nmod, 4, 参道
# の -> case, 2, 神社
# 参道 -> nsubj, 6, 暗かっ
# は -> case, 4, 参道
# 暗かっ -> root, 0, _root_
# た -> aux, 6, 暗かっ
# 。 -> punct, 6, 暗かっ
# ('下鴨', '2', 'compound')
# ('神社', '4', 'nmod')
# ('の', '2', 'case')
# ('参道', '6', 'nsubj')
# ('は', '4', 'case')
# ('暗かっ', 0, 'root')
# ('た', '6', 'aux')
# ('。', '6', 'punct')

# %%
viz_sample('ja', '私の趣味は、多くの小旅行をすることです。')
# Out:
# .. request is {'lang': 'ja', 'sents': '私の趣味は、多くの小旅行をすることです。', 'engine': 'corenlp'}
# words count 14
# ❶ verb_domains(する) _
#      rel index text lemma           children   features
# 0  nsubj     3   趣味    趣味   [私, の, 趣味, は, 、]   [c_noun]
# 1    obj     9   旅行    旅行  [多く, の, 小, 旅行, を]   [c_noun]
# 2    aux    12   こと    こと               [こと]   [c_noun]
# 3    cop    13   です     だ               [です]    [c_aux]
# 4  punct    14    。     。                [。]  [c_punct]
# nsubj -> 私 の 趣味 は 、
# obj -> 多く の 小 旅行 を
# index: 1	text: 私 	lemma: 私	upos: PRON	xpos: _
# index: 2	text: の 	lemma: の	upos: ADP	xpos: _
# index: 3	text: 趣味 	lemma: 趣味	upos: NOUN	xpos: _
# index: 4	text: は 	lemma: は	upos: ADP	xpos: _
# index: 5	text: 、 	lemma: 、	upos: PUNCT	xpos: _
# index: 6	text: 多く 	lemma: 多く	upos: NOUN	xpos: _
# index: 7	text: の 	lemma: の	upos: ADP	xpos: _
# index: 8	text: 小 	lemma: 小	upos: NOUN	xpos: _
# index: 9	text: 旅行 	lemma: 旅行	upos: NOUN	xpos: _
# index: 10	text: を 	lemma: を	upos: ADP	xpos: _
# index: 11	text: する 	lemma: する	upos: VERB	xpos: _
# index: 12	text: こと 	lemma: こと	upos: NOUN	xpos: _
# index: 13	text: です 	lemma: だ	upos: AUX	xpos: _
# index: 14	text: 。 	lemma: 。	upos: PUNCT	xpos: _
# 私 -> nmod, 3, 趣味
# の -> case, 1, 私
# 趣味 -> nsubj, 11, する
# は -> case, 3, 趣味
# 、 -> punct, 3, 趣味
# 多く -> nmod, 9, 旅行
# の -> case, 6, 多く
# 小 -> amod, 9, 旅行
# 旅行 -> obj, 11, する
# を -> case, 9, 旅行
# する -> root, 0, _root_
# こと -> aux, 11, する
# です -> cop, 11, する
# 。 -> punct, 11, する
# ('私', '3', 'nmod')
# ('の', '1', 'case')
# ('趣味', '11', 'nsubj')
# ('は', '3', 'case')
# ('、', '3', 'punct')
# ('多く', '9', 'nmod')
# ('の', '6', 'case')
# ('小', '9', 'amod')
# ('旅行', '11', 'obj')
# ('を', '9', 'case')
# ('する', 0, 'root')
# ('こと', '11', 'aux')
# ('です', '11', 'cop')
# ('。', '11', 'punct')
