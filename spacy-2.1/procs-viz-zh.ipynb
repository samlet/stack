# %%
from sagas.nlu.uni_remote_viz import viz_sample
viz_sample('zh', '国务院总理李克强调研上海外高桥时提出，支持上海积极探索新机制。', 'ltp')
# Out:
# .. request is {'lang': 'zh', 'sents': '国务院总理李克强调研上海外高桥时提出，支持上海积极探索新机制。', 'engine': 'ltp', 'pipelines': ['predicts']}
# words count 16
# ❶ verb_domains(提出) _
#    rel  index text lemma                        children         features
# 0  adv      7    时     时  [国务院, 总理, 李克强, 调研, 上海, 外高桥, 时]    [c_noun, x_n]
# 1   wp      9    ，     ，                             [，]  [c_punct, x_wp]
# 2  coo     10   支持    支持         [支持, 上海, 积极, 探索, 新, 机制]    [c_verb, x_v]
# 3   wp     16    。     。                             [。]  [c_punct, x_wp]
# adv -> 国务院 总理 李克强 调研 上海 外高桥 时
# coo -> 支持 上海 积极 探索 新 机制
# {'predicts': [{'index': 7, 'predicate': '提出', 'args': [{'name': 'TMP', 'value': '国务院总理李克强调研上海外高桥时', 'start': 0, 'end': 6}, {'name': 'A1', 'value': '支持上海积极探索新机制', 'start': 9, 'end': 14}]}, {'index': 9, 'predicate': '支持', 'args': [{'name': 'A1', 'value': '上海', 'start': 10, 'end': 10}]}]}
#     index text lemma   upos xpos
# 0       1  国务院   国务院   NOUN   ni
# 1       2   总理    总理   NOUN    n
# ...
