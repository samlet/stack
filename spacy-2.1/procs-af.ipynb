# %%
from sagas.nlu.uni_remote_viz import viz_sample
# 我 要 订 到雅典 机票 。
viz_sample('af', "Ek wil graag ’n vlug na Athene bespreek.")
# Out:
# .. request is {'lang': 'af', 'sents': 'Ek wil graag ’n vlug na Athene bespreek.', 'engine': 'corenlp', 'pipelines': ['predicts']}
# words count 9
# ✁ chunks. -------------------------
# ❶ verb_domains(bespreek) _
#       rel index    text   lemma      children           features
# 0   nsubj     1      Ek      ek          [Ek]  [c_pron, x_peenp]
# 1     aux     2     wil     wil         [wil]   [c_aux, x_vtuom]
# 2  advmod     3   graag   graag       [graag]      [c_adv, x_bs]
# 3     obj     5    vlug    vlug    [’n, vlug]    [c_noun, x_nse]
# 4     obl     7  Athene  athene  [na, Athene]     [c_noun, x_ns]
# 5   punct     9       .       .           [.]    [c_punct, x_ze]
# obj -> ’n vlug
# obl -> na athene
# ✁ dependency-graph. -------------------------
#   index      text     lemma   upos   xpos
# 0     1        Ek        ek   PRON  PEENP
# 1     2       wil       wil    AUX  VTUOM
# 2     3     graag     graag    ADV     BS
# 3     4        ’n        ’n   PRON   PDMB
# ...

# %%
viz_sample('af', 'Wanneer land ons?')
# Out:
# .. request is {'lang': 'af', 'sents': 'Wanneer land ons?', 'engine': 'corenlp', 'pipelines': ['predicts']}
# words count 4
# ✁ chunks. -------------------------
# ❶ subj_domains(land) ons(pron)
#      rel index  text lemma            children         features
# 0  nsubj     2  land  land  [Wanneer, land, ?]  [c_noun, x_nse]
# nsubj -> wanneer land ?
# ✁ dependency-graph. -------------------------
#   index     text    lemma   upos  xpos
# 0     1  Wanneer  wanneer   PRON    PB
# 1     2     land     land   NOUN   NSE
# 2     3      ons      ons   PRON  PEMP
# 3     4        ?        ?  PUNCT    ZE
